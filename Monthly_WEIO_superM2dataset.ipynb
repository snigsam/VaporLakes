# %% [markdown]
# # Make MERRA-2 super-dataset: monthly means
# ### from collections of interest
# From `https://goldsmr5.gesdisc.eosdis.nasa.gov/dods/` (goldsmr4 for 2D fields) and this [list](https://disc.gsfc.nasa.gov/information/documents?title=MERRA-2%20Data%20Collection%20Variable%20Tables) of all collections and datasets.
#
# ### Monthly: X is 2D, P is 3D
#
# M2TMNP is monthly 3D BUDGET fields, M2IMNP is monthly 3D STATE fields
#
# M2TMNX is monthly 2D BUDGET fields, M2IMNX is monthly 2D STATE fields
#
# ### Short term:
#
# M2I3NP is 3D 3-h states, M2T3NP is 3D 3-h budgets (T integral over 3 hours)
#
# M2T1NX and M2I1NX are 2D
# - again T is for fluxes/ bugdet terms and I is for state variables

# %%
import xarray as xr

# %% [markdown]
# # Read MERRA2 2D fields from GDS, combine into
# ## SUPER DATASET, select box, and write out

# %%
d2diag = xr.open_dataset('https://goldsmr4.gesdisc.eosdis.nasa.gov/dods/M2TMNXINT')
d2flux = xr.open_dataset('https://goldsmr4.gesdisc.eosdis.nasa.gov/dods/M2TMNXFLX')
d2slv = xr.open_dataset('https://goldsmr4.gesdisc.eosdis.nasa.gov/dods/M2TMNXSLV')

var_diag = ['dqvdt_phy','dqvdt_dyn','dqvdt_ana','uflxqv','vflxqv','swnettoa']
var_flux = ['eflux','evap','hflux','preccon','precanv','prectot','prevtot','prectotcorr']
var_slv = [ 't2m','ts','t850','t500','q850','q500','slp','tqv','tqi','tql'  ]
# Out:
# /Users/brianmapes/opt/miniconda3/envs/geopy/lib/python3.10/site-packages/xarray/coding/times.py:144: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:0.0. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:0.0). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
# Box: 35-95 E, 30S-30N

# %%
d2super = d2diag[ var_diag ].merge(d2flux[ var_flux ]).merge(d2slv[ var_slv ])
d2super.sel(lat=slice(-30,30),lon=slice(35,95))
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 516, lat: 121, lon: 97)
# Coordinates:
#   * time         (time) datetime64[ns] 1980-01-01 1980-02-01 ... 2022-12-01
#   * lat          (lat) float64 -30.0 -29.5 -29.0 -28.5 ... 28.5 29.0 29.5 30.0
#   * lon          (lon) float64 35.0 35.62 36.25 36.88 ... 93.12 93.75 94.38 95.0
# Data variables: (12/24)
#     dqvdt_phy    (time, lat, lon) float32 ...
#     dqvdt_dyn    (time, lat, lon) float32 ...
#     dqvdt_ana    (time, lat, lon) float32 ...
#     uflxqv       (time, lat, lon) float32 ...
#     vflxqv       (time, lat, lon) float32 ...
#     swnettoa     (time, lat, lon) float32 ...
#     ...           ...
#     q850         (time, lat, lon) float32 ...
#     q500         (time, lat, lon) float32 ...
#     slp          (time, lat, lon) float32 ...
#     tqv          (time, lat, lon) float32 ...
#     tqi          (time, lat, lon) float32 ...
#     tql          (time, lat, lon) float32 ...
# Attributes:
#     title:        MERRA-2 tavgM_2d_int_Nx: 2d,Monthly Mean,Single-Level,Assim...
#     Conventions:  COARDS\nGrADS
#     dataType:     Grid
#     history:      Mon Jan 30 17:21:46 GMT 2023 : imported by GrADS Data Serve...

# %%
# !date
# Out:
# Mon Jan 30 15:39:30 EST 2023

# %%
# Save to netCDF file 
# d2super.sel(lat=slice(-30,30),lon=slice(35,95)).to_netcdf('../../Library/CloudStorage/Box-Box/VaporLakes/data/M2_WEIO_monthly_2D_myfields.nc')

# %%
# !date # looks like it took abuot an hour, file size 10 GB or so -- oops for whole world!

# %%
globe = xr.open_dataset('../../Library/CloudStorage/Box-Box/VaporLakes/data/M2_global_monthly_2D_myfields.nc')
globe
# OOPS I Saved whole world, no wonder it is so big!
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 516, lat: 361, lon: 576)
# Coordinates:
#   * time         (time) datetime64[ns] 1980-01-01 1980-02-01 ... 2022-12-01
#   * lat          (lat) float64 -90.0 -89.5 -89.0 -88.5 ... 88.5 89.0 89.5 90.0
#   * lon          (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
# Data variables: (12/24)
#     dqvdt_phy    (time, lat, lon) float32 ...
#     dqvdt_dyn    (time, lat, lon) float32 ...
#     dqvdt_ana    (time, lat, lon) float32 ...
#     uflxqv       (time, lat, lon) float32 ...
#     vflxqv       (time, lat, lon) float32 ...
#     swnettoa     (time, lat, lon) float32 ...
#     ...           ...
#     q850         (time, lat, lon) float32 ...
#     q500         (time, lat, lon) float32 ...
#     slp          (time, lat, lon) float32 ...
#     tqv          (time, lat, lon) float32 ...
#     tqi          (time, lat, lon) float32 ...
#     tql          (time, lat, lon) float32 ...
# Attributes:
#     title:        MERRA-2 tavgM_2d_int_Nx: 2d,Monthly Mean,Single-Level,Assim...
#     Conventions:  COARDS\nGrADS
#     dataType:     Grid
#     history:      Mon Jan 30 17:21:46 GMT 2023 : imported by GrADS Data Serve...

# %% [markdown]
# # Now 3D fields

# %% [raw]
# Merra2 3D monthly fields I might want (trust)
#
# M2IMNPASM
#     QV,RH, T, U,V,OMEGA
#
# M2TMNPMST
#     CMFMC "cumulative mass flux"
#
# M2TMNPQDT moisture budget
#     DQVDTANA, DQVDTDYN, DQVDTMST, DQVDTTRB
#
# M2TMNPTDT temperature budget
#     DTDTANA, DTDTDYN, DTDTTOT, DTDTMST, DTDTTRB

# %%
# Out:
# /Users/brianmapes/opt/miniconda3/envs/geopy/lib/python3.10/site-packages/xarray/coding/times.py:144: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:0.0. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:0.0). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
d3asm = xr.open_dataset('https://goldsmr5.gesdisc.eosdis.nasa.gov/dods/M2IMNPASM')
d3mst = xr.open_dataset('https://goldsmr5.gesdisc.eosdis.nasa.gov/dods/M2TMNPMST')
d3tbu = xr.open_dataset('https://goldsmr5.gesdisc.eosdis.nasa.gov/dods/M2TMNPTDT')
d3qbu = xr.open_dataset('https://goldsmr5.gesdisc.eosdis.nasa.gov/dods/M2TMNPQDT')

# %%
vars_mst = ['cmfmc']
vars_asm = ['qv','rh','t','omega','u','v']
vars_qbu = ['dqvdtdyn','dqvdtmst','dqvdttrb','dqvdtana']
vars_tbu = ['dtdtrad','dtdtmst','dtdttot']

# %%
d3super = d3asm[ vars_asm ].merge(d3mst[ vars_mst ]).merge(d3qbu[ vars_qbu ]).merge(d3tbu[ vars_tbu ])
test = d3super.sel( lev=slice(1100,100)).sel(lat=slice(-30,30),lon=slice(35,95),time=slice('2017-01-01','2017-12-31') ).squeeze()
test
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 12, lev: 25, lat: 121, lon: 97)
# Coordinates:
#   * time      (time) datetime64[ns] 2017-01-01 2017-02-01 ... 2017-12-01
#   * lev       (lev) float64 1e+03 975.0 950.0 925.0 ... 250.0 200.0 150.0 100.0
#   * lat       (lat) float64 -30.0 -29.5 -29.0 -28.5 ... 28.5 29.0 29.5 30.0
#   * lon       (lon) float64 35.0 35.62 36.25 36.88 ... 93.12 93.75 94.38 95.0
# Data variables: (12/14)
#     qv        (time, lev, lat, lon) float32 ...
#     rh        (time, lev, lat, lon) float32 ...
#     t         (time, lev, lat, lon) float32 ...
#     omega     (time, lev, lat, lon) float32 ...
#     u         (time, lev, lat, lon) float32 ...
#     v         (time, lev, lat, lon) float32 ...
#     ...        ...
#     dqvdtmst  (time, lev, lat, lon) float32 ...
#     dqvdttrb  (time, lev, lat, lon) float32 ...
#     dqvdtana  (time, lev, lat, lon) float32 ...
#     dtdtrad   (time, lev, lat, lon) float32 ...
#     dtdtmst   (time, lev, lat, lon) float32 ...
#     dtdttot   (time, lev, lat, lon) float32 ...
# Attributes:
#     title:        MERRA-2 instM_3d_asm_Np: 3d,Monthly Mean,Pressure-Level,Ass...
#     Conventions:  COARDS\nGrADS
#     dataType:     Grid
#     history:      Mon Jan 30 17:15:54 GMT 2023 : imported by GrADS Data Serve...

# %%
# !date
# Out:
# Mon Jan 30 16:23:28 EST 2023

# %%
test.to_netcdf('../../Library/CloudStorage/Box-Box/VaporLakes/data/M2_WEIO_monthly_2017_3D_myfields.nc')
# Out:
# /Users/brianmapes/opt/miniconda3/envs/geopy/lib/python3.10/site-packages/xarray/coding/times.py:144: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:0.0. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:0.0). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
# !date
# Out:
# Mon Jan 30 16:24:39 EST 2023

# %% [raw]
# ## Merra2 2D fields I want:
#
# M2TMNXFLX
#     EFLUX, HFLUX, EVAP
#     PRECCON, PRECANV, PRECLSC, PRECTOT, PRECTOTCORR bias corrected
#
# M2TMNXINT column integrated diagnostics
#     DQVDT_ANA, DQVDT_DYN, DQVDT_PHY, DQVDT_MST, DQVDT_TRB, DQVDT_MST
#     DQVDT_FIL, QTFILL (small we hope)
#     SWNETTOA
#     UFLXQV, VFLXQV  # eastward and northward flux of vapor
#
# M2TMNXSLV "single level diagnostics"
#     T2m
#     TQV
#     T850, T500, Q850, Q500
#     TQI, TQL # (cloud depth proxies)
#     TS # skin temp
#
# M2TCNXLTM "long term mean", M2SMNXPCT "Percentiles"

# %% [raw]
# collection name of the form:
# M2TFHVGGG
# where
# T: Time Description:
#  I = Instantaneous
#  T = Time-averaged
# F: Frequency
#  1 = Hourly
#  3 = 3-Hourly
#  M = Monthly mean
# H: Horizontal Resolution
#  N = Native
# V: Vertical Location
#  X = Two-dimensional
#  P = Pressure
# GGG: Group
#  ANA = direct analysis products
#  ASM = assimilated state variables (from IAU corrector, see System Document)
#  AER = aerosol mixing ratio
#  ADG = aerosol extended diagnostics
#  TDT = tendencies of temperature
#  UDT = tendencies of eastward and northward wind components
#  QDT = tendencies of specific humidity
#  ODT = tendencies of ozone
#  GAS = aerosol optical depth
#  GLC = Land Ice Surface
#  LND = land surface variables
#  LFO = land surface forcing output
#  FLX = surface turbulent fluxes and related quantities
#  MST = moist processes
#  CLD = clouds
#  RAD = radiation
#  CSP = COSP satellite simulator
#  TRB = turbulence
#  SLV = single level
#  INT = vertical integrals
# CHM = chemistry forcing
# OCN = ocean
# NAV = vertical coordinates

# %% [markdown]
# # Monthly IMERG rainfall in 60x60 degree WEIO

# %%
imerg = xr.open_dataset('https://gpm1.gesdisc.eosdis.nasa.gov:443/dods/GPM_3IMERGM_06')
imerg.sel(lat=slice(-30,30),lon=slice(35,95))
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 256, lat: 600, lon: 600)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-06-01 2000-07-01 ... 2021-09-01
#   * lat      (lat) float64 -29.95 -29.85 -29.75 -29.65 ... 29.75 29.85 29.95
#   * lon      (lon) float64 35.05 35.15 35.25 35.35 ... 94.65 94.75 94.85 94.95
# Data variables:
#     precip   (time, lat, lon) float32 ...
# Attributes:
#     title:        GPM Level 3 IMERG Monthly 0.1 by 0.1 degree Precipitation V06
#     Conventions:  COARDS\nGrADS
#     dataType:     Grid
#     history:      Fri Feb 03 15:24:07 GMT 2023 : imported by GrADS Data Serve...

# %%
imerg.sel(lat=slice(-30,30),lon=slice(35,95)).to_netcdf('../../Library/CloudStorage/Box-Box/VaporLakes/data/IMERG_WEIO_monthly.nc')
