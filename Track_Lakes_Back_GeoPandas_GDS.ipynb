# %% [markdown]
# # Tracking tqv (column water vapor) "lakes" in WEIO
# ## tracking code (MERRA2): test with GDS
# ### suitable for running as .py (time loop is in one cell)
#
# Backward time loop to track coast-crossing vapor lakes (CCVLs) using Geopandas methods from Geopandas_overlaps.ipynb.
#
# filename=tag format is `yyyymmddhh.meanlat.55` where meanlat is the mean latitude of the overlap with a coastline and 55 mm is the tqv contour level. Some key strings: "dest" means "destined to happen", that is the prior timestep in a backward loop. "now" means the present time in that loop. "gdf_" leads off GeoDataFrames. "CCVL" is a coast-crossing vapor lake, the high-level (across-time) entity we are tracking here.

# %%
# !date
# Out:
# Fri Apr 22 16:24:47 EDT 2022

# %%
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

from shapely import geometry
import pandas as pd
import geopandas as gp

from datetime import datetime
from timeit import default_timer as timer

# %% [markdown]
# # Key parameters up top

# %%
# This takes just a few seconds!

tqv_conlevel = 55. # mm
dataURL = 'https://goldsmr4.gesdisc.eosdis.nasa.gov/dods/M2I1NXINT' # has tqv field

NHOURS = 365*24*4 # Four years 

# Open in xarray
cwv_data = xr.open_dataset(dataURL)
cwv_data
# Out:
# /Users/brianmapes/opt/miniconda3/envs/geopy/lib/python3.10/site-packages/xarray/coding/times.py:144: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:0.0. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:0.0). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# <xarray.Dataset>
# Dimensions:  (time: 369600, lat: 361, lon: 576)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T23:00:00.000003
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
# Data variables:
#     cpt      (time, lat, lon) float32 ...
#     ke       (time, lat, lon) float32 ...
#     mass     (time, lat, lon) float32 ...
#     thv      (time, lat, lon) float32 ...
#     tox      (time, lat, lon) float32 ...
#     tqi      (time, lat, lon) float32 ...
#     tql      (time, lat, lon) float32 ...
#     tqv      (time, lat, lon) float32 ...
# Attributes:
#     title:        MERRA-2 inst1_2d_int_Nx: 2d,1-Hourly,Instantaneous,Single-L...
#     Conventions:  COARDS\nGrADS
#     dataType:     Grid
#     history:      Tue Apr 19 18:05:17 GMT 2022 : imported by GrADS Data Serve...

# %% [markdown]
# # Define key functions

# %%
# A function to return a GeoDataFrame of polygons
# by looping over contour collections (and polygons in each collection) 
# and creating a list of shapes called polylist  

MAXLONLIMIT = 89 # degrees east, the Megalake 
SMALLSIZELIMIT = 1    # square degree 

def gdf_from_contours(lon,lat,tqv,conlevel):
    '''Inputs: lon, lat, tqv(lon,lat), contour level'''    

    levels = [conlevel, 9e9] # infinitely large number as second level
    cs = plt.contourf(lon,lat,tqv,levels) # filled contours return the right kind of cs
    
# create lookup table for levels, not needed for single contour level but keep it
    lvl_lookup = dict(zip(cs.collections, cs.levels))
    
    zvalues, polylist  = [], []  # zvalues, in case one wants polygons for multiple levels

    for col in cs.collections:
        z=lvl_lookup[col] # the value of this level
        for contour_path in col.get_paths():
        # create the polygon for this level
            for ncp,cp in enumerate(contour_path.to_polygons()):
                lons = np.array(cp)[:,0]
                lats = np.array(cp)[:,1]
                new_shape = geometry.Polygon([(i[0], i[1]) for i in zip(lons,lats)])            
                if ncp == 0:
                    poly = new_shape # first shape
                else:
                    poly = poly.difference(new_shape) # Remove the holes

            polylist.append(poly)
            zvalues.append(z)
            
# The magic: make a GeoPandas frame, and a few attribute columns 
        gdf = gp.GeoDataFrame(geometry=polylist)
        gdf['tqv_values']=zvalues
        gdf['area']=gdf.area
        gdf['maxlon']=gdf.bounds.maxx
        
# Only keep ones that aren't megalake (maxlon < 89), and small ones
        gdf = gdf[gdf.maxlon <MAXLONLIMIT]
        gdf = gdf[gdf.area   >SMALLSIZELIMIT]

        # re-index 
        num_now = len(gdf.index)
        gdf.index = range( num_now )

        return(gdf)

# %% [markdown]
# # Initiate some needed objects:
# #### Contours of coastal (or littoral) east Africa in 20N-S
# #### Some empty arrays defined before the loop uses them

# %%
# The littoral contours 
gdf_litt = gp.read_file('Africa_Ecoast_20NS.geojson')
#gdf_litt.plot()

ccvls_stats = [] # empty, to collect the stats of ccvls

# Subset data to the WEIO (30-90E, 30S-30N)
cwv_WEIO = cwv_data.sel(lat=slice(-30,30),lon=slice(30,90))

# To initialize before looping, process the last-most time (index -1) to a gdf
gdf_dest = gdf_from_contours(cwv_WEIO.lon,cwv_WEIO.lat,cwv_WEIO.tqv[-1],tqv_conlevel)

# Find coast-overlappers, using query_bulk which returns index arrays
i_litt, i_dest = gdf_dest.sindex.query_bulk(gdf_litt.geometry, predicate='overlaps') 
# i_litt values lie in 0,3 since there are 4 polygons in the littoral gdf

# gdf_ccvls is a SUBSET: I only care about ones that touch the coast
gdf_ccvls = gdf_dest.loc[i_dest].drop_duplicates()
# Must re-index in order for .loc[] to work later in overlap tests 
gdf_ccvls.index = range( len(gdf_ccvls.index) )

# A GeoDataFrame is 1 column with shapes, plus additional columns of attributes.
# Add data columns: time and tag (`tag` is a string, yyyymmddhh_meanlat)
## tag is useful for constructing filenames

# time (given by xarray) appears to be a datetime64 object
yyyymmddhh = cwv_WEIO.time[-1].values
print('time level: ', yyyymmddhh)
gdf_ccvls['time'] = yyyymmddhh 

# time as a string (parse through pandas, there are DIFFERENT datetimes, UGH!)
timestring = pd.to_datetime(str(yyyymmddhh)).strftime('%Y_%m_%d_%H')

# mean latitude
centlats = gdf_ccvls.geometry.centroid.y

# need tag to be a string without special characters (- nor .) 
# use N/S rather than dash for sign, and p for "point" in meanlat
# carry 5 characters of abs(meanlat), plenty enough to be unique
NS = ['N','S']
ccvltags = [  timestring+'_lat'+ str(abs(centlats[i]))[:5]   for i in range(len(centlats)) ] 
ccvltags = [ ccvltags[i] + NS[ int(centlats[i]<0) ]   for i in range(len(centlats)) ] 
ccvltags = [ ccvltags[i].replace('.','p') for i in range(len(ccvltags)) ]

gdf_ccvls['tag'] = ccvltags

# Initialize a GDF for each CCVL
### so that shapes at other times can be appended within the time loop 

# Clever trick exec(command), that's how tag can be used as a variable name

## HUGE HEADACHE with append()
## I have to subset using two-index range [0:1] to make it work
## actually, transposing may suffice, .to_frame().T, but this works.
## to make this work: ccvl_2014_05_15_23_lat5p382S.append(ccvl_2014_05_15_23_lat5p577S)

for i in range(len(gdf_ccvls)):
    command = 'ccvl_' + gdf_ccvls.iloc[i].tag + ' = gdf_ccvls.iloc[' +str(i)+':'+str(i+1)+']'
    print('creating gdf_ccvls: ', command)
    exec(command) # creates new gdf for each tag, ready to append 
    # example: 
    # ccvl_2014_05_15_23_lat5p382S = gdf_ccvls.iloc[0:1]
    # creating gdf:  ccvl_2014_06_09_07_lat4p676N = gdf_newccvl.to_frame().T
# Out:
# time level:  2022-02-28T23:00:00.000003000
# creating gdf_ccvls:  ccvl_2022_02_28_23_lat15p14S = gdf_ccvls.iloc[0:1]
# creating gdf_ccvls:  ccvl_2022_02_28_23_lat15p73S = gdf_ccvls.iloc[1:2]

# %%
# --- 
# Discussion of backward time loop action steps 
# We need to  

# 1. Check the overlap of *gdf_now* with pre-existing *gdf_ccvl* shapes
# 1. Transfer CCVL tag to any (all) overlaps with maxlon<89E , discarding others
# 1. Append all non-megalake overlappers to a GDF for each CCVL, ready to write out
# 1. Testing for CCVL birth (present in dest, absent in now). 
      # Write terminated CCVLs as .geojson, and append their duration, areatime, bounds 
      # and other stats to a big Pandas df meta-index of all CCVLs
# 1. Find new coast-crossers now, spawn as new CCVLs IFF they don't exist yet
# 1. Transfer gdf_ccvls_now to gdf_ccvls for next iteration

# %%
import warnings
warnings.filterwarnings('ignore')

# a zillion copies of 
# <string>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat insttead

# %%
start = timer()

# %debug
# Time loop over ALL hours, backward in time! This is rather dangerously long 
# for it in range( len(cwv_WEIO.time)-1 ):

# Safer: a given number of hours, like 365*24 for a year 

for it in range( NHOURS ):
    iback = -(it+2)
    timenow = cwv_WEIO.time[iback].values

    # print('time level is ', timenow) #confirms iback goes -2, -3, -4, ... 

# Step 1 in loop: create gdf_now, and find its overlaps with gdf_ccvls

    gdf_now = gdf_from_contours(cwv_WEIO.lon,cwv_WEIO.lat,cwv_WEIO.tqv[iback],tqv_conlevel)
    i_ccvls, i_now = gdf_now[(gdf_now.area>0)].sindex.query_bulk(gdf_ccvls.geometry, predicate='overlaps') 

# Step 2 in loop: copy overlappers into gdf_ccvls_now, copy tag, add time.

    # Assign gdf: gdf_ccvls_now, all 'now' objects that are part of a ccvl
    gdf_ccvls_now = gdf_now.loc[i_now]

    # Port the tags from ccvls to ccvls_now
    gdf_ccvls_now['tag'] = gdf_ccvls.iloc[i_ccvls].tag.values
    gdf_ccvls_now['time'] = cwv_WEIO.time[iback].values
    
    # Drop duplicates, and re-index in order for .iloc[] to work later in coast overlap 
    gdf_ccvls_now = gdf_ccvls_now.drop_duplicates()
    num_now = len(gdf_ccvls_now.index)
    gdf_ccvls_now.index = range( num_now )
    
    # if( num_now > 20 ): print('num_now is big: ', num_now, gdf_ccvls)

## Step 3 in loop: Append all gdf_ccvl_now rows onto 
## the existing GDFs for each CCVL, to write out as final result files.

    for iccvl in range( num_now ):
        command = 'ccvl_' + gdf_ccvls_now.iloc[iccvl].tag + ' = ' + \
                  'ccvl_' + gdf_ccvls_now.iloc[iccvl].tag + \
                  '.append(gdf_ccvls_now.iloc[' +str(iccvl)+':'+str(iccvl+1)+'])'
        # print('Step 3, iccvl, appending: ', iccvl, command)
        exec(command) 
        # Example: 
        # ccvl_2014_06_09_01_lat4p387N = ccvl_2014_06_09_01_lat4p387N
        #                               .append(gdf_ccvls_now.iloc[0:1])

## Step 4: terminate tracking of any `dest` ccvls that don't exist `now`

    orphan_tags = pd.concat( [gdf_ccvls_now.tag, gdf_ccvls.tag] ).drop_duplicates(keep=False)

    for i in range(len(orphan_tags)):
        # WRITE OUT CCVL FILE
        outfilename = str(orphan_tags.iloc[i]) + '.geojson'
        command = 'gp.GeoDataFrame(ccvl_' + str(orphan_tags.iloc[i]) + \
                  ').to_file("GEOJSONS/' + str(orphan_tags.iloc[i]) + \
                  '.geojson", driver="GeoJSON")'
        print('terminate: ', outfilename)
        exec(command)
        # Example 
        # gp.GeoDataFrame(ccvl_2014_06_09_07_lat4p676N).to_file("2014_06_09_07_lat4p676N.geojson", driver="GeoJSON")


        # GATHER ccvl_stats
        ccvlname = 'ccvl_' + str(orphan_tags.iloc[i])
        command2 = 'dummy = ' + ccvlname + '.copy()'
        exec(command2)

        areatime = dummy['area'].sum()
        maxarea = dummy['area'].max()
        duration = dummy['time'].max() - dummy['time'].min()
        tqv_values = dummy['tqv_values'].mean()
        lasttime = dummy['time'].max()
        ccvl_stats = pd.DataFrame(
            {
             "lasttime": [lasttime],
             "duration": [duration],
             "areatime": [areatime],
             "tqv_values": [tqv_values],
             "maxarea": [maxarea],
             "filename": [outfilename]
            } )
        
        print(ccvl_stats)

        # APPEND ccvl_stats TO ccvls_stats, a growindg index of all CCVLs.
        if(len(ccvls_stats)<1): ccvls_stats = ccvl_stats # first time step
        else: ccvls_stats = ccvls_stats.append(ccvl_stats) # all others

        # DELETE FROM MEMORY in long loops 
        command3 = 'del(ccvl_' + str(orphan_tags.iloc[i]) + ')'
        exec(command3) # example del(ccvl_2014_06_09_07_lat4p676N)
                       
## Step 5: Find NEW ccvl's: coast-crossers now, not in megalake

    i_litt, i_now_cc = gdf_now.sindex.query_bulk(gdf_litt.geometry, predicate='overlaps') 

    for i in np.unique(i_now_cc):  # because a shape may overlap two littoral segments
        if not (i in i_now): # i_now was the overlap of gdf_ccvls with gdf_now

            gdf_newccvl = gdf_now.iloc[i].copy()
            print('adding new ccvl: ', timenow) #gdf_newccvl)

            # add time: uh-oh, is this the same kind of datetime object?? 
            gdf_newccvl['time'] = timenow

            # add tag = timestring + str(meanlat)
            timestring = pd.to_datetime(str(timenow)).strftime('%Y_%m_%d_%H')
            centlat = gdf_newccvl.geometry.centroid.y
            ccvltags = timestring+'_lat'+ str(abs(centlat))[:5]
            ccvltags = ccvltags + NS[ int(centlat<0) ] 
            ccvltags = ccvltags.replace('.','p') 
            gdf_newccvl['tag'] = ccvltags

            # append this new ccvl to ccvls_now
            gdf_ccvls_now = gdf_ccvls_now.append(gdf_newccvl)

            # create the corresponding ccvl_tag... gdf for this new ccvl
            # in transposed form, ready to append onto in next time steps
            command = 'ccvl_' + gdf_newccvl.tag + ' = gdf_newccvl.to_frame().T' 
            exec(command) # creates new gdf
            # example ccvl_2014_06_09_07_lat4p676N = gdf_newccvl.to_frame().T

## Step 6: # re-index, and transfer gdf_ccvls_now to gdf_ccvls for next iteration

    gdf_ccvls = gdf_ccvls_now
    del(gdf_ccvls_now) # empty variable for next time
    
    # re-index 
    gdf_ccvls.index = range( len(gdf_ccvls.index) )

## That was the end of the time loop! 
## Write out ccvls_stats 
ccvls_stats.index = range( len(ccvls_stats) )
print('End of time loop: ccvls_stats')
print(ccvls_stats)
    
## Write out restart files (gdf_ccvls_dest, and the gdf's of all its lakes, ccvl_...)
## and then set up the reading-in code at initiation section 


## Write out any orphans at the last time level: should this be made into a function? 
## Need a unique screening someplace 
orphan_tags = gdf_ccvls.tag.drop_duplicates()
for i in range(len(orphan_tags)):
    # WRITE OUT CCVL FILE
    outfilename = str(orphan_tags.iloc[i]) + '.geojson'
    command = 'gp.GeoDataFrame(ccvl_' + str(orphan_tags.iloc[i]) + \
              ').to_file("GEOJSONS/' + str(orphan_tags.iloc[i]) + \
              '.geojson", driver="GeoJSON")'
    print('terminate at end of time loop: ', outfilename)
    exec(command)
    # Example 
    # gp.GeoDataFrame(ccvl_2014_06_09_07_lat4p676N).to_file("2014_06_09_07_lat4p676N.geojson", driver="GeoJSON")


    # GATHER ccvl_stats
    ccvlname = 'ccvl_' + str(orphan_tags.iloc[i])
    command2 = 'dummy = ' + ccvlname + '.copy()'
    exec(command2)

    areatime = dummy['area'].sum()
    maxarea = dummy['area'].max()
    duration = dummy['time'].max() - dummy['time'].min()
    tqv_values = dummy['tqv_values'].mean()
    lasttime = dummy['time'].max()
    ccvl_stats = pd.DataFrame(
        {
         "lasttime": [lasttime],
         "duration": [duration],
         "areatime": [areatime],
         "tqv_values": [tqv_values],
         "maxarea": [maxarea],
         "filename": [outfilename]
        } )

    print(ccvl_stats.drop_duplicates())

    # APPEND ccvl_stats TO ccvls_stats, a growindg index of all CCVLs.
    if(len(ccvls_stats)<1): ccvls_stats = ccvl_stats # first time step
    else: ccvls_stats = ccvls_stats.append(ccvl_stats) # all others

# Write out the master collection file    
ccvls_stats.to_csv('ccvls_stats.csv')

end = timer()
print(end - start, ' seconds elapsed') # Time in seconds, e.g. 5.38091952400282
# Out:
# adding new ccvl:  2022-02-27T23:00:00.000003000
# terminate:  2022_02_27_23_lat12p49S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-27 23:00:00.000003 0 days 04:00:00.000006  84.899747        55.0
#
#      maxarea                         filename
# 0  25.625271  2022_02_27_23_lat12p49S.geojson
# adding new ccvl:  2022-02-27T12:59:59.999997000
# terminate:  2022_02_28_23_lat15p73S.geojson
#                     lasttime               duration      areatime  tqv_values  \
# 0 2022-02-28 23:00:00.000003 2 days 04:00:00.000006  10891.450478        55.0
#
#       maxarea                         filename
# 0  398.955285  2022_02_28_23_lat15p73S.geojson
# terminate:  2022_02_27_12_lat14p06S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2022-02-27 12:59:59.999997 0 days 18:00:00  5918.49534        55.0
#
#       maxarea                         filename
# 0  398.955285  2022_02_27_12_lat14p06S.geojson
# adding new ccvl:  2022-02-26T17:00:00.000003000
# adding new ccvl:  2022-02-26T17:00:00.000003000
# adding new ccvl:  2022-02-26T17:00:00.000003000
# adding new ccvl:  2022-02-26T17:00:00.000003000
# terminate:  2022_02_26_17_lat18p86S.geojson
#                     lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-02-26 17:00:00.000003   0 days  45.947751        55.0  45.947751
#
#                           filename
# 0  2022_02_26_17_lat18p86S.geojson
# terminate:  2022_02_26_17_lat10p75S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-26 17:00:00.000003 0 days 01:00:00.000006  84.366238        55.0
#
#      maxarea                         filename
# 0  42.298969  2022_02_26_17_lat10p75S.geojson
# terminate:  2022_02_26_17_lat7p763S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-02-26 17:00:00.000003 0 days 01:00:00.000006  3.554453        55.0
#
#     maxarea                         filename
# 0  1.873331  2022_02_26_17_lat7p763S.geojson
# adding new ccvl:  2022-02-26T14:00:00.000003000
# terminate:  2022_02_26_14_lat19p73S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-26 14:00:00.000003 0 days 01:00:00.000006  98.549147        55.0
#
#      maxarea                         filename
# 0  49.306555  2022_02_26_14_lat19p73S.geojson
# adding new ccvl:  2022-02-26T09:59:59.999997000
# terminate:  2022_02_26_09_lat20p69S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-26 09:59:59.999997 0 days 00:59:59.999997  83.851408        55.0
#
#      maxarea                         filename
# 0  42.999403  2022_02_26_09_lat20p69S.geojson
# adding new ccvl:  2022-02-26T08:00:00.000003000
# adding new ccvl:  2022-02-26T08:00:00.000003000
# adding new ccvl:  2022-02-26T05:00:00.000003000
# terminate:  2022_02_26_17_lat15p92S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2022-02-26 17:00:00.000003 0 days 12:00:00  256.111072        55.0
#
#      maxarea                         filename
# 0  27.795653  2022_02_26_17_lat15p92S.geojson
# terminate:  2022_02_26_08_lat16p77S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-26 08:00:00.000003 0 days 04:00:00.000006  12.912733        55.0
#
#     maxarea                         filename
# 0  3.673964  2022_02_26_08_lat16p77S.geojson
# adding new ccvl:  2022-02-26T03:00:00.000000000
# terminate:  2022_02_26_03_lat16p47S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-26 03:00:00   0 days  1.100656        55.0  1.100656
#
#                           filename
# 0  2022_02_26_03_lat16p47S.geojson
# adding new ccvl:  2022-02-26T02:00:00.000003000
# terminate:  2022_02_26_02_lat7p568S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-26 02:00:00.000003   0 days  1.237196        55.0  1.237196
#
#                           filename
# 0  2022_02_26_02_lat7p568S.geojson
# adding new ccvl:  2022-02-25T23:00:00.000003000
# terminate:  2022_02_25_23_lat12p17S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-02-25 23:00:00.000003 0 days 01:00:00.000006  427.112252        55.0
#
#       maxarea                         filename
# 0  214.705912  2022_02_25_23_lat12p17S.geojson
# adding new ccvl:  2022-02-25T20:00:00.000003000
# adding new ccvl:  2022-02-24T15:59:59.999997000
# terminate:  2022_02_24_15_lat3p775S.geojson
#                     lasttime        duration   areatime  tqv_values   maxarea  \
# 0 2022-02-24 15:59:59.999997 0 days 09:00:00  16.490392        55.0  1.939197
#
#                           filename
# 0  2022_02_24_15_lat3p775S.geojson
# terminate:  2022_02_26_08_lat11p04S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-02-26 08:00:00.000003 2 days 14:00:00.000003  13823.72377        55.0
#
#      maxarea                         filename
# 0  341.74481  2022_02_26_08_lat11p04S.geojson
# terminate:  2022_02_26_05_lat11p98S.geojson
#                     lasttime               duration      areatime  tqv_values  \
# 0 2022-02-26 05:00:00.000003 2 days 11:00:00.000003  14132.981953        55.0
#
#      maxarea                         filename
# 0  341.74481  2022_02_26_05_lat11p98S.geojson
# terminate:  2022_02_25_20_lat12p95S.geojson
#                     lasttime               duration      areatime  tqv_values  \
# 0 2022-02-25 20:00:00.000003 2 days 02:00:00.000003  13402.049214        55.0
#
#      maxarea                         filename
# 0  341.74481  2022_02_25_20_lat12p95S.geojson
# adding new ccvl:  2022-02-23T14:00:00.000003000
# adding new ccvl:  2022-02-23T03:00:00.000000000
# adding new ccvl:  2022-02-23T02:00:00.000003000
# adding new ccvl:  2022-02-23T00:59:59.999997000
# terminate:  2022_02_23_02_lat12p73S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-02-23 02:00:00.000003 0 days 01:00:00.000006  9.853445        55.0
#
#     maxarea                         filename
# 0  6.332441  2022_02_23_02_lat12p73S.geojson
# adding new ccvl:  2022-02-23T00:00:00.000000000
# terminate:  2022_02_23_00_lat22p49S.geojson
#     lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-02-23   0 days  80.702478        55.0  80.702478
#
#                           filename
# 0  2022_02_23_00_lat22p49S.geojson
# adding new ccvl:  2022-02-22T21:59:59.999997000
# terminate:  2022_02_22_21_lat15p49S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2022-02-22 21:59:59.999997 0 days 09:00:00  1969.48976        55.0
#
#       maxarea                         filename
# 0  223.075926  2022_02_22_21_lat15p49S.geojson
# adding new ccvl:  2022-02-22T06:00:00.000000000
# terminate:  2022_02_22_06_lat21p37S.geojson
#              lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-02-22 06:00:00   0 days  82.066817        55.0  82.066817
#
#                           filename
# 0  2022_02_22_06_lat21p37S.geojson
# adding new ccvl:  2022-02-22T03:00:00.000000000
# terminate:  2022_02_22_03_lat21p02S.geojson
#              lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-02-22 03:00:00   0 days  87.804226        55.0  87.804226
#
#                           filename
# 0  2022_02_22_03_lat21p02S.geojson
# terminate:  2022_02_23_00_lat13p73S.geojson
#                     lasttime duration    areatime  tqv_values    maxarea  \
# 0 2022-02-23 00:59:59.999997   1 days  353.798012        55.0  32.987651
#
#                           filename
# 0  2022_02_23_00_lat13p73S.geojson
# adding new ccvl:  2022-02-21T11:00:00.000003000
# adding new ccvl:  2022-02-21T00:59:59.999997000
# adding new ccvl:  2022-02-21T00:00:00.000000000
# terminate:  2022_02_21_00_lat12p98S.geojson
#     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-21   0 days  5.652211        55.0  5.652211
#
#                           filename
# 0  2022_02_21_00_lat12p98S.geojson
# adding new ccvl:  2022-02-20T23:00:00.000003000
# terminate:  2022_02_20_23_lat13p15S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-20 23:00:00.000003   0 days  4.177055        55.0  4.177055
#
#                           filename
# 0  2022_02_20_23_lat13p15S.geojson
# adding new ccvl:  2022-02-20T21:59:59.999997000
# terminate:  2022_02_20_21_lat13p30S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-20 21:59:59.999997   0 days  2.822579        55.0  2.822579
#
#                           filename
# 0  2022_02_20_21_lat13p30S.geojson
# adding new ccvl:  2022-02-20T21:00:00.000000000
# terminate:  2022_02_20_21_lat13p39S.geojson
#              lasttime               duration  areatime  tqv_values   maxarea  \
# 0 2022-02-20 21:00:00 0 days 02:00:00.000003  6.290104        55.0  2.386818
#
#                           filename
# 0  2022_02_20_21_lat13p39S.geojson
# adding new ccvl:  2022-02-20T18:00:00.000000000
# terminate:  2022_02_21_00_lat17p87S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-02-21 00:59:59.999997 0 days 06:59:59.999997  511.227075        55.0
#
#      maxarea                         filename
# 0  65.840331  2022_02_21_00_lat17p87S.geojson
# terminate:  2022_02_20_18_lat13p83S.geojson
#              lasttime duration  areatime  tqv_values  maxarea  \
# 0 2022-02-20 18:00:00   0 days   5.11996        55.0  5.11996
#
#                           filename
# 0  2022_02_20_18_lat13p83S.geojson
# adding new ccvl:  2022-02-19T17:00:00.000003000
# terminate:  2022_02_19_17_lat5p565S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-19 17:00:00.000003   0 days  1.364368        55.0  1.364368
#
#                           filename
# 0  2022_02_19_17_lat5p565S.geojson
# adding new ccvl:  2022-02-19T15:59:59.999997000
# terminate:  2022_02_19_15_lat5p646S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-19 15:59:59.999997   0 days  2.060515        55.0  2.060515
#
#                           filename
# 0  2022_02_19_15_lat5p646S.geojson
# adding new ccvl:  2022-02-19T15:00:00.000000000
# terminate:  2022_02_19_15_lat5p781S.geojson
#              lasttime        duration   areatime  tqv_values   maxarea  \
# 0 2022-02-19 15:00:00 0 days 09:00:00  27.331482        55.0  3.204102
#
#                           filename
# 0  2022_02_19_15_lat5p781S.geojson
# adding new ccvl:  2022-02-19T03:59:59.999997000
# terminate:  2022_02_19_03_lat12p67S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-19 03:59:59.999997   0 days  1.048642        55.0  1.048642
#
#                           filename
# 0  2022_02_19_03_lat12p67S.geojson
# adding new ccvl:  2022-02-19T03:00:00.000000000
# adding new ccvl:  2022-02-18T20:00:00.000003000
# terminate:  2022_02_18_20_lat8p117S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-18 20:00:00.000003   0 days  1.686954        55.0  1.686954
#
#                           filename
# 0  2022_02_18_20_lat8p117S.geojson
# adding new ccvl:  2022-02-18T18:59:59.999997000
# terminate:  2022_02_19_03_lat12p70S.geojson
#              lasttime               duration    areatime  tqv_values  \
# 0 2022-02-19 03:00:00 1 days 09:59:59.999997  225.528125        55.0
#
#      maxarea                         filename
# 0  13.620175  2022_02_19_03_lat12p70S.geojson
# adding new ccvl:  2022-02-17T11:00:00.000003000
# terminate:  2022_02_17_11_lat18p47S.geojson
#                     lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-02-17 11:00:00.000003   0 days  47.133995        55.0  47.133995
#
#                           filename
# 0  2022_02_17_11_lat18p47S.geojson
# adding new ccvl:  2022-02-17T08:00:00.000003000
# adding new ccvl:  2022-02-17T06:00:00.000000000
# terminate:  2022_02_17_06_lat14p53S.geojson
#              lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-02-17 06:00:00   0 days  75.283866        55.0  75.283866
#
#                           filename
# 0  2022_02_17_06_lat14p53S.geojson
# adding new ccvl:  2022-02-17T03:59:59.999997000
# adding new ccvl:  2022-02-17T00:59:59.999997000
# terminate:  2022_02_17_00_lat7p301S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-17 00:59:59.999997   0 days  2.992666        55.0  2.992666
#
#                           filename
# 0  2022_02_17_00_lat7p301S.geojson
# adding new ccvl:  2022-02-17T00:00:00.000000000
# terminate:  2022_02_17_00_lat7p278S.geojson
#     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-17   0 days  2.223844        55.0  2.223844
#
#                           filename
# 0  2022_02_17_00_lat7p278S.geojson
# terminate:  2022_02_17_08_lat9p188S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2022-02-17 08:00:00.000003 0 days 09:00:00  314.889171        55.0
#
#      maxarea                         filename
# 0  37.450652  2022_02_17_08_lat9p188S.geojson
# adding new ccvl:  2022-02-16T15:00:00.000000000
# adding new ccvl:  2022-02-16T14:00:00.000003000
# terminate:  2022_02_16_14_lat17p40S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-02-16 14:00:00.000003 0 days 04:00:00.000006  7.719217        55.0
#
#     maxarea                         filename
# 0  1.771733  2022_02_16_14_lat17p40S.geojson
# adding new ccvl:  2022-02-16T03:59:59.999997000
# terminate:  2022_02_16_03_lat7p588S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-16 03:59:59.999997   0 days  1.062894        55.0  1.062894
#
#                           filename
# 0  2022_02_16_03_lat7p588S.geojson
# adding new ccvl:  2022-02-15T21:59:59.999997000
# adding new ccvl:  2022-02-15T18:59:59.999997000
# terminate:  2022_02_15_18_lat18p34S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-15 18:59:59.999997   0 days  4.833538        55.0  4.833538
#
#                           filename
# 0  2022_02_15_18_lat18p34S.geojson
# adding new ccvl:  2022-02-15T18:00:00.000000000
# terminate:  2022_02_15_18_lat18p54S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-15 18:00:00   0 days  6.999571        55.0  6.999571
#
#                           filename
# 0  2022_02_15_18_lat18p54S.geojson
# adding new ccvl:  2022-02-15T17:00:00.000003000
# adding new ccvl:  2022-02-14T21:59:59.999997000
# adding new ccvl:  2022-02-14T12:00:00.000000000
# terminate:  2022_02_14_12_lat17p27S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-14 12:00:00   0 days  1.179914        55.0  1.179914
#
#                           filename
# 0  2022_02_14_12_lat17p27S.geojson
# adding new ccvl:  2022-02-14T11:00:00.000003000
# adding new ccvl:  2022-02-14T05:00:00.000003000
# adding new ccvl:  2022-02-13T21:00:00.000000000
# terminate:  2022_02_13_21_lat17p21S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-13 21:00:00   0 days  2.197691        55.0  2.197691
#
#                           filename
# 0  2022_02_13_21_lat17p21S.geojson
# terminate:  2022_02_14_21_lat6p202S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-14 21:59:59.999997 1 days 01:59:59.999994  86.746219        55.0
#
#     maxarea                         filename
# 0  7.091559  2022_02_14_21_lat6p202S.geojson
# adding new ccvl:  2022-02-13T18:00:00.000000000
# terminate:  2022_02_14_05_lat15p90S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-02-14 05:00:00.000003 0 days 17:00:00.000003  340.169542        55.0
#
#     maxarea                         filename
# 0  23.99461  2022_02_14_05_lat15p90S.geojson
# terminate:  2022_02_17_03_lat14p45S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-02-17 03:59:59.999997 3 days 18:59:59.999997  5199.202788        55.0
#
#      maxarea                         filename
# 0  73.153196  2022_02_17_03_lat14p45S.geojson
# terminate:  2022_02_16_15_lat9p555S.geojson
#              lasttime        duration     areatime  tqv_values    maxarea  \
# 0 2022-02-16 15:00:00 3 days 06:00:00  4545.644579        55.0  67.478535
#
#                           filename
# 0  2022_02_16_15_lat9p555S.geojson
# terminate:  2022_02_15_21_lat17p23S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-02-15 21:59:59.999997 2 days 12:59:59.999997  3461.322403        55.0
#
#      maxarea                         filename
# 0  67.216681  2022_02_15_21_lat17p23S.geojson
# terminate:  2022_02_15_17_lat18p93S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-02-15 17:00:00.000003 2 days 08:00:00.000003  1784.069641        55.0
#
#      maxarea                         filename
# 0  48.276816  2022_02_15_17_lat18p93S.geojson
# terminate:  2022_02_14_11_lat17p37S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-02-14 11:00:00.000003 1 days 02:00:00.000003  781.719953        55.0
#
#      maxarea                         filename
# 0  48.276816  2022_02_14_11_lat17p37S.geojson
# adding new ccvl:  2022-02-13T08:00:00.000003000
# adding new ccvl:  2022-02-13T02:00:00.000003000
# adding new ccvl:  2022-02-13T00:59:59.999997000
# adding new ccvl:  2022-02-13T00:00:00.000000000
# adding new ccvl:  2022-02-12T21:00:00.000000000
# terminate:  2022_02_13_00_lat19p44S.geojson
#     lasttime               duration  areatime  tqv_values   maxarea  \
# 0 2022-02-13 0 days 03:59:59.999997  7.175606        55.0  1.589397
#
#                           filename
# 0  2022_02_13_00_lat19p44S.geojson
# terminate:  2022_02_13_02_lat13p09S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-13 02:00:00.000003 0 days 07:00:00.000006  32.076771        55.0
#
#     maxarea                         filename
# 0  7.635774  2022_02_13_02_lat13p09S.geojson
# terminate:  2022_02_13_00_lat14p07S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-13 00:59:59.999997 0 days 09:59:59.999997  34.564242        55.0
#
#     maxarea                         filename
# 0  8.290107  2022_02_13_00_lat14p07S.geojson
# terminate:  2022_02_12_21_lat10p71S.geojson
#              lasttime        duration   areatime  tqv_values   maxarea  \
# 0 2022-02-12 21:00:00 0 days 06:00:00  39.489328        55.0  6.884142
#
#                           filename
# 0  2022_02_12_21_lat10p71S.geojson
# adding new ccvl:  2022-02-12T12:00:00.000000000
# adding new ccvl:  2022-02-12T12:00:00.000000000
# terminate:  2022_02_13_18_lat8p612S.geojson
#              lasttime               duration    areatime  tqv_values  \
# 0 2022-02-13 18:00:00 1 days 06:59:59.999997  198.683522        55.0
#
#      maxarea                         filename
# 0  14.855649  2022_02_13_18_lat8p612S.geojson
# terminate:  2022_02_12_12_lat14p64S.geojson
#              lasttime        duration  areatime  tqv_values   maxarea  \
# 0 2022-02-12 12:00:00 0 days 03:00:00  8.966286        55.0  2.687934
#
#                           filename
# 0  2022_02_12_12_lat14p64S.geojson
# adding new ccvl:  2022-02-12T08:00:00.000003000
# terminate:  2022_02_12_08_lat15p41S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-12 08:00:00.000003   0 days  1.703551        55.0  1.703551
#
#                           filename
# 0  2022_02_12_08_lat15p41S.geojson
# adding new ccvl:  2022-02-12T00:00:00.000000000
# terminate:  2022_02_12_00_lat15p22S.geojson
#     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-12   0 days  1.761297        55.0  1.761297
#
#                           filename
# 0  2022_02_12_00_lat15p22S.geojson
# adding new ccvl:  2022-02-11T20:00:00.000003000
# adding new ccvl:  2022-02-11T17:00:00.000003000
# terminate:  2022_02_11_17_lat8p715S.geojson
#                     lasttime        duration   areatime  tqv_values   maxarea  \
# 0 2022-02-11 17:00:00.000003 0 days 06:00:00  23.192367        55.0  4.239782
#
#                           filename
# 0  2022_02_11_17_lat8p715S.geojson
# terminate:  2022_02_13_08_lat16p64S.geojson
#                     lasttime        duration     areatime  tqv_values  \
# 0 2022-02-13 08:00:00.000003 2 days 12:00:00  1557.226214        55.0
#
#     maxarea                         filename
# 0  68.02407  2022_02_13_08_lat16p64S.geojson
# terminate:  2022_02_12_12_lat10p93S.geojson
#              lasttime               duration     areatime  tqv_values  \
# 0 2022-02-12 12:00:00 1 days 15:59:59.999997  1637.724418        55.0
#
#     maxarea                         filename
# 0  68.02407  2022_02_12_12_lat10p93S.geojson
# terminate:  2022_02_11_20_lat11p60S.geojson
#                     lasttime duration     areatime  tqv_values   maxarea  \
# 0 2022-02-11 20:00:00.000003   1 days  1113.514325        55.0  68.02407
#
#                           filename
# 0  2022_02_11_20_lat11p60S.geojson
# adding new ccvl:  2022-02-10T06:59:59.999997000
# terminate:  2022_02_10_06_lat13p82S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-02-10 06:59:59.999997 0 days 10:59:59.999994  625.593783        55.0
#
#      maxarea                         filename
# 0  58.077378  2022_02_10_06_lat13p82S.geojson
# adding new ccvl:  2022-02-09T12:59:59.999997000
# adding new ccvl:  2022-02-09T09:00:00.000000000
# adding new ccvl:  2022-02-09T03:59:59.999997000
# terminate:  2022_02_09_03_lat11p56S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-09 03:59:59.999997   0 days  3.699085        55.0  3.699085
#
#                           filename
# 0  2022_02_09_03_lat11p56S.geojson
# adding new ccvl:  2022-02-09T03:00:00.000000000
# terminate:  2022_02_09_03_lat11p74S.geojson
#              lasttime               duration  areatime  tqv_values   maxarea  \
# 0 2022-02-09 03:00:00 0 days 00:59:59.999997  3.114127        55.0  2.091152
#
#                           filename
# 0  2022_02_09_03_lat11p74S.geojson
# adding new ccvl:  2022-02-08T21:00:00.000000000
# terminate:  2022_02_08_21_lat16p80S.geojson
#              lasttime               duration   areatime  tqv_values   maxarea  \
# 0 2022-02-08 21:00:00 0 days 05:00:00.000003  22.794861        55.0  5.484645
#
#                           filename
# 0  2022_02_08_21_lat16p80S.geojson
# adding new ccvl:  2022-02-07T21:59:59.999997000
# terminate:  2022_02_07_21_lat13p57S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-02-07 21:59:59.999997 0 days 03:59:59.999997  6.406116        55.0
#
#     maxarea                         filename
# 0  1.433353  2022_02_07_21_lat13p57S.geojson
# adding new ccvl:  2022-02-07T09:00:00.000000000
# adding new ccvl:  2022-02-07T06:59:59.999997000
# terminate:  2022_02_07_06_lat17p03S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-07 06:59:59.999997   0 days  5.365658        55.0  5.365658
#
#                           filename
# 0  2022_02_07_06_lat17p03S.geojson
# adding new ccvl:  2022-02-07T06:00:00.000000000
# terminate:  2022_02_07_06_lat16p83S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-07 06:00:00   0 days  3.839756        55.0  3.839756
#
#                           filename
# 0  2022_02_07_06_lat16p83S.geojson
# adding new ccvl:  2022-02-07T05:00:00.000003000
# terminate:  2022_02_07_05_lat16p55S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-07 05:00:00.000003   0 days  2.454576        55.0  2.454576
#
#                           filename
# 0  2022_02_07_05_lat16p55S.geojson
# adding new ccvl:  2022-02-07T03:59:59.999997000
# terminate:  2022_02_07_03_lat16p19S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-07 03:59:59.999997   0 days  1.060451        55.0  1.060451
#
#                           filename
# 0  2022_02_07_03_lat16p19S.geojson
# adding new ccvl:  2022-02-05T17:00:00.000003000
# terminate:  2022_02_05_17_lat16p54S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-05 17:00:00.000003 0 days 04:00:00.000006  825.76309        55.0
#
#       maxarea                         filename
# 0  166.987427  2022_02_05_17_lat16p54S.geojson
# adding new ccvl:  2022-02-05T00:59:59.999997000
# terminate:  2022_02_05_00_lat16p21S.geojson
#                     lasttime        duration     areatime  tqv_values  \
# 0 2022-02-05 00:59:59.999997 0 days 18:00:00  2773.279785        55.0
#
#       maxarea                         filename
# 0  171.852666  2022_02_05_00_lat16p21S.geojson
# adding new ccvl:  2022-02-04T00:59:59.999997000
# terminate:  2022_02_04_00_lat11p63S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-04 00:59:59.999997   0 days  1.306569        55.0  1.306569
#
#                           filename
# 0  2022_02_04_00_lat11p63S.geojson
# adding new ccvl:  2022-02-04T00:00:00.000000000
# terminate:  2022_02_04_00_lat11p65S.geojson
#     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-04   0 days  1.770023        55.0  1.770023
#
#                           filename
# 0  2022_02_04_00_lat11p65S.geojson
# adding new ccvl:  2022-02-03T23:00:00.000003000
# adding new ccvl:  2022-02-03T21:00:00.000000000
# adding new ccvl:  2022-02-03T14:00:00.000003000
# terminate:  2022_02_03_14_lat14p44S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-03 14:00:00.000003   0 days  2.140749        55.0  2.140749
#
#                           filename
# 0  2022_02_03_14_lat14p44S.geojson
# terminate:  2022_02_09_12_lat25p21S.geojson
#                     lasttime               duration      areatime  tqv_values  \
# 0 2022-02-09 12:59:59.999997 6 days 01:59:59.999994  10576.891194        55.0
#
#       maxarea                         filename
# 0  174.343496  2022_02_09_12_lat25p21S.geojson
# terminate:  2022_02_09_09_lat14p99S.geojson
#              lasttime               duration      areatime  tqv_values  \
# 0 2022-02-09 09:00:00 5 days 21:59:59.999997  11038.475542        55.0
#
#       maxarea                         filename
# 0  174.343496  2022_02_09_09_lat14p99S.geojson
# terminate:  2022_02_07_09_lat7p029S.geojson
#              lasttime               duration     areatime  tqv_values  \
# 0 2022-02-07 09:00:00 3 days 21:59:59.999997  1874.652335        55.0
#
#      maxarea                         filename
# 0  36.826264  2022_02_07_09_lat7p029S.geojson
# terminate:  2022_02_03_23_lat11p65S.geojson
#                     lasttime        duration   areatime  tqv_values  \
# 0 2022-02-03 23:00:00.000003 0 days 12:00:00  69.552663        55.0
#
#      maxarea                         filename
# 0  10.454536  2022_02_03_23_lat11p65S.geojson
# adding new ccvl:  2022-02-03T09:59:59.999997000
# adding new ccvl:  2022-02-03T09:59:59.999997000
# terminate:  2022_02_03_09_lat11p74S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-03 09:59:59.999997   0 days  2.953392        55.0  2.953392
#
#                           filename
# 0  2022_02_03_09_lat11p74S.geojson
# adding new ccvl:  2022-02-03T09:00:00.000000000
# terminate:  2022_02_03_09_lat11p74S.geojson
#              lasttime               duration  areatime  tqv_values   maxarea  \
# 0 2022-02-03 09:00:00 0 days 00:59:59.999997  3.661615        55.0  2.272037
#
#                           filename
# 0  2022_02_03_09_lat11p74S.geojson
# terminate:  2022_02_03_21_lat17p95S.geojson
#              lasttime        duration     areatime  tqv_values    maxarea  \
# 0 2022-02-03 21:00:00 0 days 21:00:00  1502.015465        55.0  78.123732
#
#                           filename
# 0  2022_02_03_21_lat17p95S.geojson
# terminate:  2022_02_03_09_lat9p211S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-02-03 09:59:59.999997 0 days 10:59:59.999994  20.227407        55.0
#
#     maxarea                         filename
# 0  3.216006  2022_02_03_09_lat9p211S.geojson
# adding new ccvl:  2022-02-02T21:59:59.999997000
# adding new ccvl:  2022-02-02T15:00:00.000000000
# terminate:  2022_02_02_15_lat19p85S.geojson
#              lasttime               duration    areatime  tqv_values  maxarea  \
# 0 2022-02-02 15:00:00 0 days 02:00:00.000003  265.898257        55.0  89.4308
#
#                           filename
# 0  2022_02_02_15_lat19p85S.geojson
# adding new ccvl:  2022-02-02T08:00:00.000003000
# terminate:  2022_02_02_08_lat7p638S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-02-02 08:00:00.000003 0 days 01:00:00.000006  9.907722        55.0
#
#     maxarea                         filename
# 0  5.811025  2022_02_02_08_lat7p638S.geojson
# terminate:  2022_02_02_21_lat8p361S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-02-02 21:59:59.999997 0 days 15:59:59.999997  230.197651        55.0
#
#      maxarea                         filename
# 0  56.899674  2022_02_02_21_lat8p361S.geojson
# adding new ccvl:  2022-02-02T05:00:00.000003000
# terminate:  2022_02_02_05_lat12p88S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-02 05:00:00.000003   0 days  4.545546        55.0  4.545546
#
#                           filename
# 0  2022_02_02_05_lat12p88S.geojson
# adding new ccvl:  2022-02-02T03:59:59.999997000
# terminate:  2022_02_02_03_lat12p84S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-02 03:59:59.999997   0 days  5.419741        55.0  5.419741
#
#                           filename
# 0  2022_02_02_03_lat12p84S.geojson
# adding new ccvl:  2022-02-02T03:00:00.000000000
# adding new ccvl:  2022-02-02T02:00:00.000003000
# terminate:  2022_02_02_02_lat9p443S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-02-02 02:00:00.000003 0 days 10:00:00.000006  221.609963        55.0
#
#      maxarea                         filename
# 0  38.047555  2022_02_02_02_lat9p443S.geojson
# adding new ccvl:  2022-02-01T15:00:00.000000000
# terminate:  2022_02_01_15_lat13p11S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-01 15:00:00   0 days  1.152941        55.0  1.152941
#
#                           filename
# 0  2022_02_01_15_lat13p11S.geojson
# adding new ccvl:  2022-02-01T03:00:00.000000000
# terminate:  2022_02_01_03_lat8p257S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-02-01 03:00:00   0 days  1.742619        55.0  1.742619
#
#                           filename
# 0  2022_02_01_03_lat8p257S.geojson
# adding new ccvl:  2022-02-01T02:00:00.000003000
# adding new ccvl:  2022-02-01T02:00:00.000003000
# terminate:  2022_02_01_02_lat15p35S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-02-01 02:00:00.000003 0 days 01:00:00.000006  790.405584        55.0
#
#       maxarea                         filename
# 0  397.092221  2022_02_01_02_lat15p35S.geojson
# terminate:  2022_02_01_02_lat8p369S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-02-01 02:00:00.000003 0 days 02:00:00.000003  8.583921        55.0
#
#     maxarea                         filename
# 0  3.193866  2022_02_01_02_lat8p369S.geojson
# adding new ccvl:  2022-01-31T21:00:00.000000000
# adding new ccvl:  2022-01-31T20:00:00.000003000
# terminate:  2022_01_31_20_lat7p802S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-31 20:00:00.000003   0 days  1.502706        55.0  1.502706
#
#                           filename
# 0  2022_01_31_20_lat7p802S.geojson
# adding new ccvl:  2022-01-31T18:59:59.999997000
# terminate:  2022_01_31_21_lat10p54S.geojson
#              lasttime               duration   areatime  tqv_values   maxarea  \
# 0 2022-01-31 21:00:00 0 days 05:00:00.000003  20.359879        55.0  4.686065
#
#                           filename
# 0  2022_01_31_21_lat10p54S.geojson
# terminate:  2022_01_31_18_lat7p778S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-01-31 18:59:59.999997 0 days 06:59:59.999997  17.40072        55.0
#
#     maxarea                         filename
# 0  2.416659  2022_01_31_18_lat7p778S.geojson
# adding new ccvl:  2022-01-31T11:00:00.000003000
# adding new ccvl:  2022-01-31T09:59:59.999997000
# terminate:  2022_01_31_11_lat7p692S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-01-31 11:00:00.000003 0 days 01:00:00.000006  3.150636        55.0
#
#     maxarea                         filename
# 0  1.722514  2022_01_31_11_lat7p692S.geojson
# terminate:  2022_01_31_09_lat9p883S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-01-31 09:59:59.999997 0 days 00:59:59.999997  2.106957        55.0
#
#     maxarea                         filename
# 0  1.053691  2022_01_31_09_lat9p883S.geojson
# adding new ccvl:  2022-01-31T06:00:00.000000000
# adding new ccvl:  2022-01-31T00:59:59.999997000
# terminate:  2022_01_31_06_lat11p37S.geojson
#              lasttime               duration     areatime  tqv_values  \
# 0 2022-01-31 06:00:00 0 days 06:59:59.999997  2374.255034        55.0
#
#       maxarea                         filename
# 0  395.909279  2022_01_31_06_lat11p37S.geojson
# adding new ccvl:  2022-01-30T21:00:00.000000000
# adding new ccvl:  2022-01-30T20:00:00.000003000
# terminate:  2022_01_30_20_lat14p42S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-01-30 20:00:00.000003 0 days 02:00:00.000003  1113.332322        55.0
#
#       maxarea                         filename
# 0  376.898899  2022_01_30_20_lat14p42S.geojson
# adding new ccvl:  2022-01-30T12:59:59.999997000
# terminate:  2022_02_02_03_lat12p83S.geojson
#              lasttime               duration    areatime  tqv_values  \
# 0 2022-02-02 03:00:00 2 days 14:00:00.000003  199.930944        55.0
#
#     maxarea                         filename
# 0  6.232701  2022_02_02_03_lat12p83S.geojson
# adding new ccvl:  2022-01-30T02:00:00.000003000
# terminate:  2022_01_30_02_lat12p73S.geojson
#                     lasttime        duration   areatime  tqv_values  \
# 0 2022-01-30 02:00:00.000003 0 days 06:00:00  52.054706        55.0
#
#      maxarea                         filename
# 0  11.813941  2022_01_30_02_lat12p73S.geojson
# adding new ccvl:  2022-01-29T15:59:59.999997000
# terminate:  2022_01_29_15_lat8p142S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2022-01-29 15:59:59.999997 0 days 12:00:00  175.463509        55.0
#
#      maxarea                         filename
# 0  33.261062  2022_01_29_15_lat8p142S.geojson
# adding new ccvl:  2022-01-28T12:00:00.000000000
# terminate:  2022_01_28_12_lat12p17S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-28 12:00:00   0 days  1.054783        55.0  1.054783
#
#                           filename
# 0  2022_01_28_12_lat12p17S.geojson
# terminate:  2022_01_30_12_lat10p82S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-01-30 12:59:59.999997 2 days 01:59:59.999994  587.264269        55.0
#
#      maxarea                         filename
# 0  27.311527  2022_01_30_12_lat10p82S.geojson
# terminate:  2022_01_31_00_lat9p365S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2022-01-31 00:59:59.999997 2 days 15:00:00  681.109782        55.0
#
#      maxarea                         filename
# 0  19.582731  2022_01_31_00_lat9p365S.geojson
# terminate:  2022_01_30_21_lat12p17S.geojson
#              lasttime               duration    areatime  tqv_values  \
# 0 2022-01-30 21:00:00 2 days 11:00:00.000003  659.960525        55.0
#
#      maxarea                         filename
# 0  19.582731  2022_01_30_21_lat12p17S.geojson
# adding new ccvl:  2022-01-27T20:00:00.000003000
# terminate:  2022_01_27_20_lat13p51S.geojson
#                     lasttime duration  areatime  tqv_values  maxarea  \
# 0 2022-01-27 20:00:00.000003   0 days   1.46183        55.0  1.46183
#
#                           filename
# 0  2022_01_27_20_lat13p51S.geojson
# adding new ccvl:  2022-01-27T18:59:59.999997000
# terminate:  2022_01_27_18_lat13p39S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-27 18:59:59.999997   0 days  2.559435        55.0  2.559435
#
#                           filename
# 0  2022_01_27_18_lat13p39S.geojson
# adding new ccvl:  2022-01-27T18:00:00.000000000
# terminate:  2022_01_27_18_lat13p34S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-27 18:00:00   0 days  3.583826        55.0  3.583826
#
#                           filename
# 0  2022_01_27_18_lat13p34S.geojson
# adding new ccvl:  2022-01-27T17:00:00.000003000
# terminate:  2022_01_27_17_lat13p26S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-27 17:00:00.000003   0 days  5.389046        55.0  5.389046
#
#                           filename
# 0  2022_01_27_17_lat13p26S.geojson
# adding new ccvl:  2022-01-27T15:59:59.999997000
# adding new ccvl:  2022-01-27T15:00:00.000000000
# terminate:  2022_01_27_15_lat7p860S.geojson
#              lasttime               duration  areatime  tqv_values   maxarea  \
# 0 2022-01-27 15:00:00 0 days 00:59:59.999997  2.242753        55.0  1.125014
#
#                           filename
# 0  2022_01_27_15_lat7p860S.geojson
# adding new ccvl:  2022-01-26T00:00:00.000000000
# terminate:  2022_01_27_15_lat13p44S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-01-27 15:59:59.999997 2 days 15:59:59.999997  4529.311338        55.0
#
#      maxarea                         filename
# 0  144.52772  2022_01_27_15_lat13p44S.geojson
# terminate:  2022_01_26_00_lat15p96S.geojson
#     lasttime duration     areatime  tqv_values    maxarea  \
# 0 2022-01-26   1 days  1119.973964        55.0  144.52772
#
#                           filename
# 0  2022_01_26_00_lat15p96S.geojson
# adding new ccvl:  2022-01-24T05:00:00.000003000
# terminate:  2022_01_24_05_lat14p21S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-01-24 05:00:00.000003 0 days 08:00:00.000003  1544.798894        55.0
#
#       maxarea                         filename
# 0  195.290657  2022_01_24_05_lat14p21S.geojson
# adding new ccvl:  2022-01-23T14:00:00.000003000
# terminate:  2022_01_23_14_lat14p47S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-01-23 14:00:00.000003 0 days 01:00:00.000006  386.117198        55.0
#
#       maxarea                         filename
# 0  194.067949  2022_01_23_14_lat14p47S.geojson
# adding new ccvl:  2022-01-23T09:59:59.999997000
# terminate:  2022_01_23_09_lat15p31S.geojson
#                     lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-01-23 09:59:59.999997   0 days  184.37303        55.0  184.37303
#
#                           filename
# 0  2022_01_23_09_lat15p31S.geojson
# adding new ccvl:  2022-01-23T03:59:59.999997000
# terminate:  2022_01_23_03_lat21p20S.geojson
#                     lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-01-23 03:59:59.999997   0 days  10.091482        55.0  10.091482
#
#                           filename
# 0  2022_01_23_03_lat21p20S.geojson
# adding new ccvl:  2022-01-23T00:59:59.999997000
# terminate:  2022_01_23_00_lat7p578S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2022-01-23 00:59:59.999997 0 days 01:59:59.999994  14.543388        55.0
#
#     maxarea                         filename
# 0  8.260865  2022_01_23_00_lat7p578S.geojson
# adding new ccvl:  2022-01-22T21:59:59.999997000
# adding new ccvl:  2022-01-21T20:00:00.000003000
# terminate:  2022_01_21_20_lat4p275S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-01-21 20:00:00.000003 0 days 05:00:00.000003  7.831502        55.0
#
#     maxarea                         filename
# 0  1.560912  2022_01_21_20_lat4p275S.geojson
# adding new ccvl:  2022-01-21T11:00:00.000003000
# terminate:  2022_01_21_11_lat4p940S.geojson
#                     lasttime duration  areatime  tqv_values  maxarea  \
# 0 2022-01-21 11:00:00.000003   0 days   1.29645        55.0  1.29645
#
#                           filename
# 0  2022_01_21_11_lat4p940S.geojson
# adding new ccvl:  2022-01-21T09:59:59.999997000
# terminate:  2022_01_21_09_lat5p045S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-21 09:59:59.999997   0 days  2.021343        55.0  2.021343
#
#                           filename
# 0  2022_01_21_09_lat5p045S.geojson
# terminate:  2022_01_22_21_lat16p18S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-01-22 21:59:59.999997 1 days 12:59:59.999997  5705.783319        55.0
#
#      maxarea                         filename
# 0  242.16728  2022_01_22_21_lat16p18S.geojson
# adding new ccvl:  2022-01-20T06:00:00.000000000
# terminate:  2022_01_20_06_lat12p61S.geojson
#              lasttime        duration     areatime  tqv_values     maxarea  \
# 0 2022-01-20 06:00:00 0 days 03:00:00  1275.710099        55.0  428.492094
#
#                           filename
# 0  2022_01_20_06_lat12p61S.geojson
# adding new ccvl:  2022-01-19T21:59:59.999997000
# adding new ccvl:  2022-01-19T20:00:00.000003000
# adding new ccvl:  2022-01-18T17:00:00.000003000
# terminate:  2022_01_18_17_lat6p863S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-18 17:00:00.000003   0 days  3.442801        55.0  3.442801
#
#                           filename
# 0  2022_01_18_17_lat6p863S.geojson
# adding new ccvl:  2022-01-18T15:59:59.999997000
# terminate:  2022_01_18_15_lat23p02S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2022-01-18 15:59:59.999997 0 days 03:00:00  320.970935        55.0
#
#     maxarea                         filename
# 0  81.89992  2022_01_18_15_lat23p02S.geojson
# adding new ccvl:  2022-01-17T18:59:59.999997000
# adding new ccvl:  2022-01-17T14:00:00.000003000
# terminate:  2022_01_17_14_lat14p54S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-17 14:00:00.000003   0 days  1.076293        55.0  1.076293
#
#                           filename
# 0  2022_01_17_14_lat14p54S.geojson
# adding new ccvl:  2022-01-16T21:00:00.000000000
# terminate:  2022_01_16_21_lat25p28S.geojson
#              lasttime duration   areatime  tqv_values    maxarea  \
# 0 2022-01-16 21:00:00   0 days  72.542702        55.0  72.542702
#
#                           filename
# 0  2022_01_16_21_lat25p28S.geojson
# terminate:  2022_01_17_18_lat16p55S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-01-17 18:59:59.999997 1 days 03:59:59.999997  2549.835321        55.0
#
#       maxarea                         filename
# 0  144.985571  2022_01_17_18_lat16p55S.geojson
# adding new ccvl:  2022-01-16T09:59:59.999997000
# adding new ccvl:  2022-01-16T03:59:59.999997000
# terminate:  2022_01_16_09_lat23p62S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2022-01-16 09:59:59.999997 0 days 07:59:59.999994  535.714178        55.0
#
#      maxarea                         filename
# 0  71.742851  2022_01_16_09_lat23p62S.geojson
# terminate:  2022_01_16_03_lat16p79S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-01-16 03:59:59.999997 0 days 01:59:59.999994  3.340268        55.0
#
#    maxarea                         filename
# 0   1.2323  2022_01_16_03_lat16p79S.geojson
# adding new ccvl:  2022-01-15T21:59:59.999997000
# terminate:  2022_01_15_21_lat12p81S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-15 21:59:59.999997   0 days  2.466358        55.0  2.466358
#
#                           filename
# 0  2022_01_15_21_lat12p81S.geojson
# adding new ccvl:  2022-01-15T21:00:00.000000000
# adding new ccvl:  2022-01-15T20:00:00.000003000
# adding new ccvl:  2022-01-15T18:00:00.000000000
# terminate:  2022_01_15_21_lat12p78S.geojson
#              lasttime        duration   areatime  tqv_values   maxarea  \
# 0 2022-01-15 21:00:00 0 days 03:00:00  15.135158        55.0  3.943589
#
#                           filename
# 0  2022_01_15_21_lat12p78S.geojson
# adding new ccvl:  2022-01-15T17:00:00.000003000
# terminate:  2022_01_15_17_lat12p44S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-15 17:00:00.000003   0 days  2.886275        55.0  2.886275
#
#                           filename
# 0  2022_01_15_17_lat12p44S.geojson
# adding new ccvl:  2022-01-15T15:59:59.999997000
# adding new ccvl:  2022-01-15T15:59:59.999997000
# terminate:  2022_01_15_20_lat10p89S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2022-01-15 20:00:00.000003 0 days 04:00:00.000006  2122.252315        55.0
#
#       maxarea                         filename
# 0  444.972201  2022_01_15_20_lat10p89S.geojson
# terminate:  2022_01_15_15_lat12p42S.geojson
#                     lasttime duration  areatime  tqv_values  maxarea  \
# 0 2022-01-15 15:59:59.999997   0 days   2.08994        55.0  2.08994
#
#                           filename
# 0  2022_01_15_15_lat12p42S.geojson
# adding new ccvl:  2022-01-15T15:00:00.000000000
# terminate:  2022_01_15_15_lat12p30S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-15 15:00:00   0 days  1.020511        55.0  1.020511
#
#                           filename
# 0  2022_01_15_15_lat12p30S.geojson
# terminate:  2022_01_15_18_lat9p500S.geojson
#              lasttime               duration   areatime  tqv_values   maxarea  \
# 0 2022-01-15 18:00:00 0 days 03:59:59.999997  11.887515        55.0  3.302885
#
#                           filename
# 0  2022_01_15_18_lat9p500S.geojson
# terminate:  2022_01_15_15_lat16p31S.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2022-01-15 15:59:59.999997 0 days 03:59:59.999997  9.794993        55.0
#
#     maxarea                         filename
# 0  2.436487  2022_01_15_15_lat16p31S.geojson
# adding new ccvl:  2022-01-15T09:59:59.999997000
# adding new ccvl:  2022-01-12T09:59:59.999997000
# terminate:  2022_01_12_09_lat16p88S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-12 09:59:59.999997   0 days  4.118995        55.0  4.118995
#
#                           filename
# 0  2022_01_12_09_lat16p88S.geojson
# adding new ccvl:  2022-01-12T09:00:00.000000000
# terminate:  2022_01_12_09_lat16p85S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-12 09:00:00   0 days  2.790373        55.0  2.790373
#
#                           filename
# 0  2022_01_12_09_lat16p85S.geojson
# adding new ccvl:  2022-01-12T08:00:00.000003000
# terminate:  2022_01_12_08_lat16p82S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2022-01-12 08:00:00.000003   0 days  1.680913        55.0  1.680913
#
#                           filename
# 0  2022_01_12_08_lat16p82S.geojson
# adding new ccvl:  2022-01-12T02:00:00.000003000
# terminate:  2022_01_12_02_lat16p61S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# ...
# 0 2018-03-17 12:59:59.999997 0 days 03:59:59.999997  11.697237        55.0
#
#     maxarea                         filename
# 0  2.579756  2018_03_17_12_lat7p845S.geojson
# adding new ccvl:  2018-03-16T20:00:00.000003000
# terminate:  2018_03_16_20_lat0p682N.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2018-03-16 20:00:00.000003 0 days 01:00:00.000006   5.30253        55.0
#
#     maxarea                         filename
# 0  2.741137  2018_03_16_20_lat0p682N.geojson
# adding new ccvl:  2018-03-15T21:00:00.000000000
# terminate:  2018_03_15_21_lat6p840S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2018-03-15 21:00:00   0 days  1.047522        55.0  1.047522
#
#                           filename
# 0  2018_03_15_21_lat6p840S.geojson
# adding new ccvl:  2018-03-15T20:00:00.000003000
# adding new ccvl:  2018-03-14T20:00:00.000003000
# adding new ccvl:  2018-03-14T20:00:00.000003000
# terminate:  2018_03_14_20_lat8p160S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2018-03-14 20:00:00.000003   0 days  1.060961        55.0  1.060961
#
#                           filename
# 0  2018_03_14_20_lat8p160S.geojson
# adding new ccvl:  2018-03-14T15:00:00.000000000
# adding new ccvl:  2018-03-14T14:00:00.000003000
# terminate:  2018_03_14_14_lat0p414N.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2018-03-14 14:00:00.000003   0 days  1.320401        55.0  1.320401
#
#                           filename
# 0  2018_03_14_14_lat0p414N.geojson
# adding new ccvl:  2018-03-14T12:59:59.999997000
# terminate:  2018_03_14_12_lat13p45S.geojson
#                     lasttime duration    areatime  tqv_values     maxarea  \
# 0 2018-03-14 12:59:59.999997   0 days  121.340972        55.0  121.340972
#
#                           filename
# 0  2018_03_14_12_lat13p45S.geojson
# adding new ccvl:  2018-03-14T11:00:00.000003000
# terminate:  2018_03_14_15_lat14p99S.geojson
#              lasttime               duration   areatime  tqv_values   maxarea  \
# 0 2018-03-14 15:00:00 0 days 20:00:00.000003  52.568034        55.0  3.484052
#
#                           filename
# 0  2018_03_14_15_lat14p99S.geojson
# terminate:  2018_03_14_11_lat13p33S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2018-03-14 11:00:00.000003 1 days 09:00:00  4781.37449        55.0
#
#      maxarea                         filename
# 0  221.28604  2018_03_14_11_lat13p33S.geojson
# adding new ccvl:  2018-03-12T17:00:00.000003000
# terminate:  2018_03_12_17_lat16p65S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2018-03-12 17:00:00.000003   0 days  1.152332        55.0  1.152332
#
#                           filename
# 0  2018_03_12_17_lat16p65S.geojson
# terminate:  2018_03_20_15_lat20p63S.geojson
#                     lasttime               duration      areatime  tqv_values  \
# 0 2018-03-20 15:59:59.999997 8 days 00:59:59.999997  17826.452083        55.0
#
#      maxarea                         filename
# 0  221.28604  2018_03_20_15_lat20p63S.geojson
# terminate:  2018_03_20_03_lat14p97S.geojson
#              lasttime        duration      areatime  tqv_values    maxarea  \
# 0 2018-03-20 03:00:00 7 days 12:00:00  17018.802765        55.0  221.28604
#
#                           filename
# 0  2018_03_20_03_lat14p97S.geojson
# terminate:  2018_03_20_03_lat12p35S.geojson
#              lasttime        duration      areatime  tqv_values    maxarea  \
# 0 2018-03-20 03:00:00 7 days 12:00:00  17020.504163        55.0  221.28604
#
#                           filename
# 0  2018_03_20_03_lat12p35S.geojson
# terminate:  2018_03_19_12_lat9p306S.geojson
#              lasttime        duration      areatime  tqv_values    maxarea  \
# 0 2018-03-19 12:00:00 6 days 21:00:00  16021.266048        55.0  221.28604
#
#                           filename
# 0  2018_03_19_12_lat9p306S.geojson
# terminate:  2018_03_18_18_lat7p323S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2018-03-18 18:59:59.999997 6 days 03:59:59.999997  4449.401284        55.0
#
#      maxarea                         filename
# 0  221.28604  2018_03_18_18_lat7p323S.geojson
# terminate:  2018_03_18_17_lat9p252S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2018-03-18 17:00:00.000003 6 days 02:00:00.000003  4380.172686        55.0
#
#      maxarea                         filename
# 0  221.28604  2018_03_18_17_lat9p252S.geojson
# terminate:  2018_03_15_20_lat7p055S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2018-03-15 20:00:00.000003 3 days 05:00:00.000003  3494.409751        55.0
#
#      maxarea                         filename
# 0  221.28604  2018_03_15_20_lat7p055S.geojson
# terminate:  2018_03_14_20_lat8p545S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2018-03-14 20:00:00.000003 2 days 05:00:00.000003  2911.01565        55.0
#
#      maxarea                         filename
# 0  221.28604  2018_03_14_20_lat8p545S.geojson
# adding new ccvl:  2018-03-12T12:59:59.999997000
# adding new ccvl:  2018-03-12T08:00:00.000003000
# adding new ccvl:  2018-03-12T03:59:59.999997000
# terminate:  2018_03_12_08_lat23p26S.geojson
#                     lasttime        duration   areatime  tqv_values  maxarea  \
# 0 2018-03-12 08:00:00.000003 0 days 06:00:00  49.892638        55.0  8.81848
#
#                           filename
# 0  2018_03_12_08_lat23p26S.geojson
# terminate:  2018_03_12_03_lat9p123S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2018-03-12 03:59:59.999997 0 days 09:00:00  496.338847        55.0
#
#      maxarea                         filename
# 0  58.850907  2018_03_12_03_lat9p123S.geojson
# terminate:  2018_03_12_12_lat18p38S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2018-03-12 12:59:59.999997 0 days 21:59:59.999997  267.194177        55.0
#
#    maxarea                         filename
# 0   67.963  2018_03_12_12_lat18p38S.geojson
# adding new ccvl:  2018-03-11T14:00:00.000003000
# terminate:  2018_03_11_14_lat11p46S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2018-03-11 14:00:00.000003 0 days 18:00:00  970.475416        55.0
#
#      maxarea                         filename
# 0  71.594723  2018_03_11_14_lat11p46S.geojson
# adding new ccvl:  2018-03-10T17:00:00.000003000
# adding new ccvl:  2018-03-10T03:00:00.000000000
# terminate:  2018_03_10_17_lat9p253S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2018-03-10 17:00:00.000003 0 days 16:00:00.000006  453.291968        55.0
#
#      maxarea                         filename
# 0  37.853204  2018_03_10_17_lat9p253S.geojson
# terminate:  2018_03_10_03_lat15p65S.geojson
#              lasttime               duration   areatime  tqv_values  maxarea  \
# 0 2018-03-10 03:00:00 0 days 03:59:59.999997  19.010747        55.0  4.99746
#
#                           filename
# 0  2018_03_10_03_lat15p65S.geojson
# adding new ccvl:  2018-03-09T12:00:00.000000000
# adding new ccvl:  2018-03-09T09:59:59.999997000
# terminate:  2018_03_09_09_lat12p22S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2018-03-09 09:59:59.999997   0 days  47.12643        55.0  47.12643
#
#                           filename
# 0  2018_03_09_09_lat12p22S.geojson
# terminate:  2018_03_09_12_lat17p81S.geojson
#              lasttime               duration  areatime  tqv_values  maxarea  \
# 0 2018-03-09 12:00:00 0 days 03:59:59.999997  19.33924        55.0  5.36899
#
#                           filename
# 0  2018_03_09_12_lat17p81S.geojson
# adding new ccvl:  2018-03-09T06:59:59.999997000
# terminate:  2018_03_09_06_lat18p20S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2018-03-09 06:59:59.999997   0 days  2.218735        55.0  2.218735
#
#                           filename
# 0  2018_03_09_06_lat18p20S.geojson
# adding new ccvl:  2018-03-09T06:00:00.000000000
# terminate:  2018_03_09_06_lat12p11S.geojson
#              lasttime               duration    areatime  tqv_values  \
# 0 2018-03-09 06:00:00 0 days 09:59:59.999997  247.091777        55.0
#
#      maxarea                         filename
# 0  30.371704  2018_03_09_06_lat12p11S.geojson
# adding new ccvl:  2018-03-08T08:00:00.000003000
# terminate:  2018_03_08_08_lat14p37S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2018-03-08 08:00:00.000003 0 days 02:00:00.000003  1076.807963        55.0
#
#       maxarea                         filename
# 0  359.754703  2018_03_08_08_lat14p37S.geojson
# adding new ccvl:  2018-03-08T03:00:00.000000000
# adding new ccvl:  2018-03-07T05:00:00.000003000
# terminate:  2018_03_07_05_lat17p98S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2018-03-07 05:00:00.000003 0 days 08:00:00.000003  2413.475144        55.0
#
#       maxarea                         filename
# 0  285.046751  2018_03_07_05_lat17p98S.geojson
# adding new ccvl:  2018-03-06T09:00:00.000000000
# adding new ccvl:  2018-03-06T05:00:00.000003000
# terminate:  2018_03_06_05_lat11p14S.geojson
#                     lasttime duration   areatime  tqv_values    maxarea  \
# 0 2018-03-06 05:00:00.000003   0 days  76.266238        55.0  76.266238
#
#                           filename
# 0  2018_03_06_05_lat11p14S.geojson
# adding new ccvl:  2018-03-06T03:00:00.000000000
# terminate:  2018_03_06_09_lat16p64S.geojson
#              lasttime        duration   areatime  tqv_values   maxarea  \
# 0 2018-03-06 09:00:00 0 days 06:00:00  27.603755        55.0  4.680134
#
#                           filename
# 0  2018_03_06_09_lat16p64S.geojson
# adding new ccvl:  2018-03-06T02:00:00.000003000
# terminate:  2018_03_06_02_lat17p23S.geojson
#                     lasttime duration  areatime  tqv_values   maxarea  \
# 0 2018-03-06 02:00:00.000003   0 days  1.413852        55.0  1.413852
#
#                           filename
# 0  2018_03_06_02_lat17p23S.geojson
# adding new ccvl:  2018-03-05T15:59:59.999997000
# terminate:  2018_03_05_15_lat3p912S.geojson
#                     lasttime               duration    areatime  tqv_values  \
# 0 2018-03-05 15:59:59.999997 0 days 09:59:59.999997  134.630751        55.0
#
#      maxarea                         filename
# 0  14.017509  2018_03_05_15_lat3p912S.geojson
# adding new ccvl:  2018-03-05T03:00:00.000000000
# terminate:  2018_03_05_03_lat12p80S.geojson
#              lasttime               duration    areatime  tqv_values  \
# 0 2018-03-05 03:00:00 0 days 00:59:59.999997  178.888789        55.0
#
#      maxarea                         filename
# 0  90.452715  2018_03_05_03_lat12p80S.geojson
# adding new ccvl:  2018-03-04T21:59:59.999997000
# adding new ccvl:  2018-03-04T21:00:00.000000000
# terminate:  2018_03_04_21_lat1p509S.geojson
#              lasttime duration  areatime  tqv_values   maxarea  \
# 0 2018-03-04 21:00:00   0 days  1.366086        55.0  1.366086
#
#                           filename
# 0  2018_03_04_21_lat1p509S.geojson
# terminate:  2018_03_04_21_lat0p800N.geojson
#                     lasttime        duration  areatime  tqv_values    maxarea  \
# 0 2018-03-04 21:59:59.999997 0 days 03:00:00  30.60647        55.0  10.658075
#
#                           filename
# 0  2018_03_04_21_lat0p800N.geojson
# adding new ccvl:  2018-03-04T03:59:59.999997000
# terminate:  2018_03_04_03_lat14p46S.geojson
#                     lasttime duration    areatime  tqv_values     maxarea  \
# 0 2018-03-04 03:59:59.999997   0 days  295.197092        55.0  295.197092
#
#                           filename
# 0  2018_03_04_03_lat14p46S.geojson
# adding new ccvl:  2018-03-04T02:00:00.000003000
# terminate:  2018_03_04_02_lat1p792S.geojson
#                     lasttime               duration   areatime  tqv_values  \
# 0 2018-03-04 02:00:00.000003 0 days 04:00:00.000006  19.282484        55.0
#
#     maxarea                         filename
# 0  4.528036  2018_03_04_02_lat1p792S.geojson
# adding new ccvl:  2018-03-03T15:59:59.999997000
# terminate:  2018_03_03_15_lat0p480N.geojson
#                     lasttime               duration  areatime  tqv_values  \
# 0 2018-03-03 15:59:59.999997 0 days 01:59:59.999994  5.455159        55.0
#
#     maxarea                         filename
# 0  2.364901  2018_03_03_15_lat0p480N.geojson
# adding new ccvl:  2018-03-03T12:59:59.999997000
# terminate:  2018_03_03_12_lat12p59S.geojson
#                     lasttime        duration    areatime  tqv_values  \
# 0 2018-03-03 12:59:59.999997 0 days 06:00:00  2882.46602        55.0
#
#       maxarea                         filename
# 0  425.849498  2018_03_03_12_lat12p59S.geojson
# adding new ccvl:  2018-03-03T03:59:59.999997000
# terminate:  2018_03_03_03_lat21p04S.geojson
#                     lasttime        duration   areatime  tqv_values   maxarea  \
# 0 2018-03-03 03:59:59.999997 0 days 03:00:00  15.982624        55.0  8.214661
#
#                           filename
# 0  2018_03_03_03_lat21p04S.geojson
# adding new ccvl:  2018-03-02T15:59:59.999997000
# adding new ccvl:  2018-03-02T09:00:00.000000000
# adding new ccvl:  2018-03-02T02:00:00.000003000
# End of time loop: ccvls_stats
#                        lasttime               duration      areatime  \
# 0    2022-02-28 23:00:00.000003 1 days 04:00:00.000006    403.382389
# 1    2022-02-27 23:00:00.000003 0 days 04:00:00.000006     84.899747
# 2    2022-02-27 23:00:00.000003 0 days 04:00:00.000006     84.899747
# 3    2022-02-28 23:00:00.000003 2 days 04:00:00.000006  10891.450478
# 4    2022-02-27 12:59:59.999997        0 days 18:00:00   5918.495340
# ...                         ...                    ...           ...
# 2742 2018-03-04 03:59:59.999997        0 days 00:00:00    295.197092
# 2743 2018-03-04 02:00:00.000003 0 days 04:00:00.000006     19.282484
# 2744 2018-03-03 15:59:59.999997 0 days 01:59:59.999994      5.455159
# 2745 2018-03-03 12:59:59.999997        0 days 06:00:00   2882.466020
# 2746 2018-03-03 03:59:59.999997        0 days 03:00:00     15.982624
#
#       tqv_values     maxarea                         filename
# 0           55.0   25.625271  2022_02_28_23_lat15p14S.geojson
# 1           55.0   25.625271  2022_02_27_23_lat12p49S.geojson
# 2           55.0   25.625271  2022_02_27_23_lat12p49S.geojson
# 3           55.0  398.955285  2022_02_28_23_lat15p73S.geojson
# 4           55.0  398.955285  2022_02_27_12_lat14p06S.geojson
# ...          ...         ...                              ...
# 2742        55.0  295.197092  2018_03_04_03_lat14p46S.geojson
# 2743        55.0    4.528036  2018_03_04_02_lat1p792S.geojson
# 2744        55.0    2.364901  2018_03_03_15_lat0p480N.geojson
# 2745        55.0  425.849498  2018_03_03_12_lat12p59S.geojson
# 2746        55.0    8.214661  2018_03_03_03_lat21p04S.geojson
#
# [2747 rows x 6 columns]
# terminate at end of time loop:  2018_03_02_15_lat9p429S.geojson
#                     lasttime               duration     areatime  tqv_values  \
# 0 2018-03-02 15:59:59.999997 0 days 16:59:59.999994  5334.687478        55.0
#
#       maxarea                         filename
# 0  470.258889  2018_03_02_15_lat9p429S.geojson
# terminate at end of time loop:  2018_03_02_09_lat0p592N.geojson
#              lasttime               duration   areatime  tqv_values   maxarea  \
# 0 2018-03-02 09:00:00 0 days 09:59:59.999997  84.048796        55.0  9.124369
#
#                           filename
# 0  2018_03_02_09_lat0p592N.geojson
# terminate at end of time loop:  2018_03_02_02_lat18p85S.geojson
#                     lasttime        duration  areatime  tqv_values   maxarea  \
# 0 2018-03-02 02:00:00.000003 0 days 03:00:00  6.245155        55.0  2.342925
#
#                           filename
# 0  2018_03_02_02_lat18p85S.geojson
# 62388.076428234024  seconds elapsed

# %% [markdown]
# # Examine some outputs

# %%
def showme(filename):   # like '2014_05_15_02_lat9p247N.geojson'
    gdf = gp.read_file(filename)
    fig, ax = plt.subplots()
    ax.set_aspect('equal')
    ax.set_xlim(30, 93)
    ax.set_ylim(-30,30)
    ax.set_title(filename)

    gdf.drop_duplicates().plot(ax=ax, column='time', facecolor='none', alpha=1) #, legend=True)

    #gdf.boundary.plot(ax=ax, color='black')
    
    path = gp.datasets.get_path('naturalearth_lowres')
    mapdf = gp.read_file(path)
    mapdf.boundary.plot(ax=ax)
    # print(gdf)
    return(gdf)

# %%
df = pd.read_csv('ccvls_stats.csv')
df
# Out:
#       Unnamed: 0             lasttime          duration       areatime  \
# 0              0  2018-12-31 23:00:00   0 days 13:00:00    2570.685677
# 1              1  2018-12-30 16:00:00   0 days 15:00:00      39.620679
# 2              2  2018-12-27 23:00:00   0 days 11:00:00      29.779736
# 3              3  2018-12-27 10:00:00   0 days 17:00:00      42.804936
# 4              4  2018-12-26 10:00:00   0 days 00:00:00       2.194071
# ...          ...                  ...               ...            ...
# 2700           0  2014-01-22 04:00:00  21 days 04:00:00  106376.665743
# 2701           0  2014-01-16 18:00:00  15 days 18:00:00   85793.559576
# 2702           0  2014-01-12 15:00:00  11 days 15:00:00   67879.437595
# 2703           0  2014-01-10 09:00:00   9 days 09:00:00   57732.467913
# 2704           0  2014-01-03 13:00:00   2 days 13:00:00   12507.403161
#
#       tqv_values     maxarea                         filename
# 0           55.0  267.411157  2018_12_31_23_lat7p515N.geojson
# 1           55.0    6.297093  2018_12_30_16_lat18p16S.geojson
# 2           55.0    3.714629  2018_12_27_23_lat12p93S.geojson
# 3           55.0    3.904742  2018_12_27_10_lat15p48S.geojson
# 4           55.0    2.194071  2018_12_26_10_lat13p45S.geojson
# ...          ...         ...                              ...
# 2700        55.0  450.351350  2014_01_22_04_lat22p70S.geojson
# 2701        55.0  450.351350  2014_01_16_18_lat22p00S.geojson
# 2702        55.0  450.351350  2014_01_12_15_lat18p24S.geojson
# 2703        55.0  450.351350  2014_01_10_09_lat12p51S.geojson
# 2704        55.0  265.968399  2014_01_03_13_lat15p44S.geojson
#
# [2705 rows x 7 columns]

# %%
biggies = df.sort_values('areatime', ascending=False)[0:10]
biggies
# Out:
#       Unnamed: 0             lasttime          duration       areatime  \
# 2698           0  2014-01-28 05:00:00  27 days 05:00:00  140314.954315
# 2699           0  2014-01-22 20:00:00  21 days 20:00:00  107567.000475
# 2700           0  2014-01-22 04:00:00  21 days 04:00:00  106376.665743
# 2263        2263  2015-01-18 01:00:00  10 days 12:00:00   86650.431899
# 2701           0  2014-01-16 18:00:00  15 days 18:00:00   85793.559576
# 589          589  2018-01-15 17:00:00  11 days 14:00:00   76016.117437
# 2702           0  2014-01-12 15:00:00  11 days 15:00:00   67879.437595
# 639          639  2017-12-20 14:00:00  11 days 20:00:00   66789.610035
# 2703           0  2014-01-10 09:00:00   9 days 09:00:00   57732.467913
# 1654        1654  2016-01-26 17:00:00   4 days 19:00:00   57156.558526
#
#       tqv_values     maxarea                         filename
# 2698        55.0  450.351350  2014_01_28_05_lat11p47S.geojson
# 2699        55.0  450.351350  2014_01_22_20_lat11p97S.geojson
# 2700        55.0  450.351350  2014_01_22_04_lat22p70S.geojson
# 2263        55.0  430.645702  2015_01_18_01_lat19p43S.geojson
# 2701        55.0  450.351350  2014_01_16_18_lat22p00S.geojson
# 589         55.0  397.221642  2018_01_15_17_lat13p94S.geojson
# 2702        55.0  450.351350  2014_01_12_15_lat18p24S.geojson
# 639         55.0  313.427667  2017_12_20_14_lat11p56S.geojson
# 2703        55.0  450.351350  2014_01_10_09_lat12p51S.geojson
# 1654        55.0  602.410193  2016_01_26_17_lat13p22S.geojson

# %%
for file in biggies.filename: 
    gdf = showme('GEOJSONS/'+file)

# %%
longduration = df.sort_values('duration', ascending=False)[0:10]
longduration
# Out:
#       Unnamed: 0             lasttime         duration      areatime  \
# 2513        2513  2014-04-17 08:00:00  9 days 21:00:00  12842.860142
# 2514        2514  2014-04-17 06:00:00  9 days 19:00:00  12712.592278
# 1759        1759  2015-12-23 13:00:00  9 days 18:00:00   5750.342293
# 625          625  2017-12-29 07:00:00  9 days 17:00:00   9524.130325
# 975          975  2017-04-29 11:00:00  9 days 15:00:00   7449.014372
# 973          973  2017-04-29 11:00:00  9 days 15:00:00   7493.295378
# 974          974  2017-04-29 11:00:00  9 days 15:00:00   8972.043947
# 590          590  2018-01-13 17:00:00  9 days 14:00:00  54144.405837
# 2471        2471  2014-05-11 18:00:00  9 days 09:00:00   6060.850143
# 2193        2193  2015-02-27 10:00:00  9 days 09:00:00  22775.354693
#
#       tqv_values     maxarea                         filename
# 2513        55.0  110.043930  2014_04_17_08_lat17p45S.geojson
# 2514        55.0  110.043930  2014_04_17_06_lat6p223S.geojson
# 1759        55.0   52.758027  2015_12_23_13_lat20p57S.geojson
# 625         55.0   77.557244  2017_12_29_07_lat13p53S.geojson
# 975         55.0   97.229094  2017_04_29_11_lat10p92N.geojson
# 973         55.0   97.229094  2017_04_29_11_lat7p001S.geojson
# 974         55.0  121.819141  2017_04_29_11_lat0p732S.geojson
# 590         55.0  352.936667  2018_01_13_17_lat20p79S.geojson
# 2471        55.0   72.174952  2014_05_11_18_lat2p131S.geojson
# 2193        55.0  218.583429  2015_02_27_10_lat15p24S.geojson

# %%
for file in longduration.filename: 
    gdf = showme('GEOJSONS/'+file)

# %%
end = timer()
print(end - start, ' seconds elapsed') # Time in seconds, e.g. 5.38091952400282
