# %%
# !date
# Out:
# Sat Jun 12 00:16:14 MDT 2021

# %%
# Backward time loop to track coast-crossing vapor lakes (CCVLs)
### using Geopandas methods from Geopandas_overlaps.ipynb

### tag format is `yyyymmddhh_at_coast.meanlat`

# where meanlat is the mean latitude of the overlap with a coastline 

from shapely import geometry
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import os         

from glob import glob
import xarray as xr

import pandas as pd
import geopandas as gp
from datetime import datetime

# A function to return a GeoDataFrame of polygons 
# loop over contour collections (and polygons in each collection)
# store in polylist  
def gdf_from_contours(lon,lat,tqv,conlevel):
    
    levels = [conlevel, 9e9]
    cs = plt.contourf(lon,lat,tqv,levels)
# create lookup table for levels
    lvl_lookup = dict(zip(cs.collections, cs.levels))
    
    zvalues, polylist  = [], []
#    i=0
    for col in cs.collections:
        z=lvl_lookup[col] # the value of this level
        for contour_path in col.get_paths():
#        print('contour path: ',i); i = i+1
        # create the polygon for this level
            for ncp,cp in enumerate(contour_path.to_polygons()):
#            print('   ncp: ', ncp)
                lons = np.array(cp)[:,0]
                lats = np.array(cp)[:,1]
                new_shape = geometry.Polygon([(i[0], i[1]) for i in zip(lons,lats)])            
                if ncp == 0:
                    poly = new_shape # first shape
                else:
                    poly = poly.difference(new_shape) # Remove the holes

            polylist.append(poly)
            zvalues.append(z)
        
        gdf = gp.GeoDataFrame(geometry=polylist)
        gdf['tqv_values']=zvalues
        gdf['area']=gdf.area
        gdf['maxlon']=gdf.bounds.maxx
        return(gdf)

gdf_litt = gp.read_file('Africa_Ecoast_20NS.geojson')
#gdf_litt.plot()


# Open the virtual (time series) dataset in xarray

files = glob('MERRA2*/MERRA2*.nc') #+glob('*2015*')+glob('*2016*')+glob('*2017*')+glob('*2018*') # selecting 2014-2018
cwv_data = xr.open_mfdataset(files) # merging data files in one
cwv_WEIO = cwv_data.sel(lat=slice(-30,30),lon=slice(30,90))

# To initialize the cycle, process the last-most time (index -1) to a gdf

ccvls_stats = [] # empty, to collect the stats of ccvls

# dest means destined, the future time level in a reverse time loop
# Initially, it is the -1 element of the data, and we need a first coast-overlap test
gdf_dest = gdf_from_contours(cwv_WEIO.lon,cwv_WEIO.lat,cwv_WEIO.TQV[-1],55.)

# Make gdf_ccvls containing only the coast-overlappers

i_litt, i_dest = gdf_dest.sindex.query_bulk(gdf_litt.geometry, predicate='overlaps') 
# i_litt, i_dest # littoral is in 0,3 since there are 4 polygons in the littoral gdf

# XXXXXX DELETE ME FOr debug challenge, suppose i_dest = [2,3] has >1 elements
# XXXXXXXX       i_dest = [2,3,6]

# ccvls is a SUBSET: I only care about the ones that touch the coast
gdf_ccvls = gdf_dest.loc[i_dest]

# Must re-index in order for .loc[] to work later in overlap tests 
gdf_ccvls.index = range( len(gdf_ccvls.index) )
gdf_ccvls  

# Add data columns: time [-1], and tag (string with meanlat)
## tag is useful as a filename, and maybe as the name of a ccvl's gdf 

# Because a geometry may be tied to more then one CCVL, 
# I need the tags column of gdf_ccvls to be a *list* of strings, not a string. 
# So to assign it, I need a *list of lists* of strings to set it equal to.
# UPDATE: no need for this, overlap just makes duplicate of either the tag or the geometry

# time as numpy datetime object
yyyymmddhh = cwv_WEIO.time[-1].values
gdf_ccvls['time'] = yyyymmddhh 

# time as a string (have to parse through pandas, UGH!)
timestring = pd.to_datetime(str(yyyymmddhh)).strftime('%Y_%m_%d_%H')

# mean latitude as a string with N/S rather than dash for sign
centlats = gdf_ccvls.geometry.centroid.y
NS = ['N','S']

# list of `tag` strings with no - nor . characters, ready to add as a new data column
ccvltag = [  timestring+'_lat'+ str(abs(centlats[i]))[:5]   for i in range(len(centlats)) ] 
ccvltag = [ ccvltag[i] + NS[ int(centlats[i]<0) ]   for i in range(len(centlats)) ] 
ccvltag = [ ccvltag[i].replace('.','p') for i in range(len(ccvltag)) ]

gdf_ccvls['tag'] = ccvltag
gdf_ccvls

# Initialize a GDF for each CCVL
### so that shapes at other times can be appended, within the time loop 

# Clever trick exec() so the tag can be used as a variable name
## HUGE HEADACHE with append(), have to subset using two-index method to make it work
# ccvl_2014_05_15_23_lat5p382S = gdf_ccvls.iloc[0:1]
#    ready for ccvl_2014_05_15_23_lat5p382S.append(ccvl_2014_05_15_23_lat5p577S)
#    del(variable) is how you remove it from memory

for i in range(len(gdf_ccvls)):
    command = 'ccvl_' + gdf_ccvls.iloc[i].tag + ' = gdf_ccvls.iloc[' +str(i)+':'+str(i+1)+']'
    print('creating gdf_ccvls: ', command)
    exec(command) # creates new gdf for each tag, ready to append 

#----------
# Time loop over hours, backward in time

for i in range( len(cwv_WEIO.time)-1 ):
    iback = -(i+2)
    print('time level is ', iback) #confirms iback goes -2, -3, -4, ... 

    #iback = -2 # XXXXX DEBUG for testing; remove to free up the loop 

# Discussion of backward time loop action steps 
# We need to be 

# 1. Checking the overlap of *new* and *ccvl* shapes
# 1. Transferring CCVL tag to any (all) overlapper shapes, discarding non-overlappers
# 1. Appending all non-megalake overlappers to a GDF for each CCVL, ready to write out
# 1. Testing for CCVL birth (present in dest, absent in now). Write terminated CCVLs as .geojson, and append their duration, areatime, bounds and other stats to a big Pandas df meta-index of all CCVLs
# 1. Find new coast-crossers now, spawn as new CCVLs IFF they don't exist yet
# 1. Transfer gdf_ccvls_now to gdf_ccvls for next iteration

# One tricky question is where and how to build up a GDF for each CCVL. Sub-questions include how to spawn & name these CCVL GDFs, how to append, and how to retire them after writeout for memory savings. 

## Step 1 in loop: check overlap of CCVLs and now-shapes

    gdf_now = gdf_from_contours(cwv_WEIO.lon,cwv_WEIO.lat,cwv_WEIO.TQV[iback],55.)
    print('time is: ', cwv_WEIO.time[iback].values) # print now time, for debugging

### Step 1 basic plots for debugging: red is now, blue is dest

#     #https://geopandas.org/docs/user_guide/mapping.html
#     fig, ax = plt.subplots()
#     ax.set_aspect('equal')
#     ax.set_xlim(30, 93)
#     ax.set_ylim(-20,20)

#     gdf_dest.plot(ax=ax,color='blue', edgecolor='black')
#     gdf_now.boundary.plot(ax=ax, color='red')
#     gdf_litt.plot(ax=ax, color='green')

#     path = gp.datasets.get_path('naturalearth_lowres')
#     mapdf = gp.read_file(path)
#     mapdf.plot(ax=ax)

### Still step 1: find overlaps

    i_ccvls, i_now = gdf_now[(gdf_now.area>0)].sindex.query_bulk(gdf_ccvls.geometry, predicate='overlaps') # index numbers of overlaps
    i_ccvls, i_now

    gdf_now.loc[i_now] # debug

    gdf_ccvls.loc[i_ccvls] # debug

## Step 2 in loop: copy overlappers into gdf_ccvls_now, copy tag, add time 

    # Assign a new gdf: gdf_ccvls_now, all now objects that are part of a ccvl
    gdf_ccvls_now = gdf_now.loc[i_now]
    
    # Port the tags from ccvls to ccvls_now 
    gdf_ccvls_now['tag'] = gdf_ccvls.iloc[i_ccvls].tag.values
    gdf_ccvls_now['time'] = cwv_WEIO.time[iback].values

    # Only keep ones that aren't megalake (maxlon < 89)
    gdf_ccvls_now = gdf_ccvls_now[gdf_ccvls_now.maxlon<89]
    
    gdf_ccvls_now

## Step 3 in loop: Append all ccvl_now to the existing GDF for each CCVL, each 
#### ready to write out as a file. Appending to a copy is probably inefficient

    for i in range(len(gdf_ccvls_now)):
        command = 'ccvl_' + gdf_ccvls_now.iloc[i].tag + ' = ' + \
                  'ccvl_' + gdf_ccvls_now.iloc[i].tag + \
                  '.append(gdf_ccvls_now.iloc[' +str(i)+':'+str(i+1)+'])'
        print('Step 3 appending: ', command)
        exec(command) # creates new gdf for each tag, ready to append 

# ----------------
## Step 4: test to terminate tracking of any destined ccvls that don't exist now
# 1. objects in ccvls that have no match now (borns)
# 2. objects now with maxlon>90 (cutoffs from EIO Meghalake) - HANDLED IN STEP2


## TEST DEBUG to create orphans 
#    i_ccvls=[0,0,0] # and then run from Step2 
#gdf_ccvls_now


# Must re-index in order for .loc[] to work later in overlap tests 
    gdf_ccvls.index = range( len(gdf_ccvls.index) )

    # Find the orphans, write and perhaps delete from memory
    orphan_tags = pd.concat( [gdf_ccvls_now.tag, gdf_ccvls.tag] ).drop_duplicates(keep=False)

    for i in range(len(orphan_tags)):
        # WRITE OUT CCVL
        command = 'gp.GeoDataFrame(ccvl_' + str(orphan_tags.iloc[i]) + \
                  ').to_file("' + str(orphan_tags.iloc[i]) + \
                  '.geojson", driver="GeoJSON")'
        print('orphan, terminate. command: ', command)
        exec(command)

        # GATHER STATS ccvl_stats, APPEND TO GROWING META-INDEX OF CCVLs, use dummy copy
        command2 = 'dummy = ccvl_' + str(orphan_tags.iloc[i]) + '.copy()'
        print('command2: ', command2)
        exec(command2)

        #ccvl_stats
        areatime = dummy['area'].sum()
        maxarea = dummy['area'].max()
        duration = dummy['time'].max() - dummy['time'].min()
        tqv_values = dummy['tqv_values'].mean()
        lasttime = dummy['time'].max()
        ccvl_stats = pd.DataFrame(
            {
             "lasttime": [lasttime],
             "duration": [duration],
             "areatime": [areatime],
             "tqv_values": [tqv_values],
             "maxarea": [maxarea]
            } )
        if(len(ccvls_stats)<1): ccvls_stats = ccvl_stats
        else: ccvls_stats = ccvls_stats.append(ccvl_stats)

        # DELETE FROM MEMORY in long loops 
        command3 = 'del(ccvl_' + str(orphan_tags.iloc[i]) + ')'
        print('command3: ', command3)
        exec(command3)                       

# Test written-out file
#tgf = gp.read_file("2014_05_15_23_lat2p998S.geojson")
#tgf
#tgf.plot(column='time', alpha=0.3)

## Step 5: Find new coast-crossers now (now_cc). 
### Spawn as new CCVLs, IFF they don't exist in i_now

    i_litt, i_now_cc = gdf_now.sindex.query_bulk(gdf_litt.geometry, predicate='overlaps') 
#    i_litt, i_now_cc # littoral is in 0,3 since there are 4 polygons in the littoral gdf
# i_now # these were the ones already part of a CCVL

    for i in i_now_cc: 
        if not (i in i_now): 
            print('adding new ccvl: ', i)
            gdf_newccvl = gdf_now.iloc[i].copy()

            # add time
            timenow = cwv_WEIO.time[iback].values
            gdf_newccvl['time'] = timenow

            # add tag = timestring + str(meanlat)
            timestring = pd.to_datetime(str(timenow)).strftime('%Y_%m_%d_%H')
            centlat = gdf_newccvl.geometry.centroid.y
            ccvltag = timestring+'_lat'+ str(abs(centlat))[:5]
            ccvltag = ccvltag + NS[ int(centlat<0) ] 
            ccvltag = ccvltag.replace('.','p') 
            gdf_newccvl['tag'] = ccvltag

            # append to ccvls_now
            gdf_ccvls_now = gdf_ccvls_now.append(gdf_newccvl)

            # create the corresponding gdf_ccvl for this new ccvl
            # in transposed form ready to append to later
            command = 'ccvl_' + gdf_newccvl.tag + ' = gdf_newccvl.to_frame().T' 
            print('creating gdf: ', command)
            exec(command) # creates new gdf

## Step 6: Transfer gdf_ccvls_now to gdf_ccvls for next iteration, re-indexing

    gdf_ccvls = gdf_ccvls_now
    # Must re-index in order for .loc[] to work later in overlap tests 
    gdf_ccvls.index = range( len(gdf_ccvls.index) )

## Write out ccvls_stats 
    
    
## Write out restart files (gdf_ccvls_dest, and the gdf's of all its lakes, ccvl_...)
## and then set up the reading-in code at initiation section
# Out:
# time level is  -2
# time is:  2014-06-30T22:00:00.000000000
# time level is  -3
# time is:  2014-06-30T21:00:00.000000000
# time level is  -4
# time is:  2014-06-30T20:00:00.000000000
# time level is  -5
# time is:  2014-06-30T19:00:00.000000000
# time level is  -6
# time is:  2014-06-30T18:00:00.000000000
# time level is  -7
# time is:  2014-06-30T17:00:00.000000000
# time level is  -8
# time is:  2014-06-30T16:00:00.000000000
# time level is  -9
# time is:  2014-06-30T15:00:00.000000000
# time level is  -10
# time is:  2014-06-30T14:00:00.000000000
# time level is  -11
# time is:  2014-06-30T13:00:00.000000000
# time level is  -12
# time is:  2014-06-30T12:00:00.000000000
# time level is  -13
# time is:  2014-06-30T11:00:00.000000000
# time level is  -14
# time is:  2014-06-30T10:00:00.000000000
# time level is  -15
# time is:  2014-06-30T09:00:00.000000000
# time level is  -16
# time is:  2014-06-30T08:00:00.000000000
# time level is  -17
# time is:  2014-06-30T07:00:00.000000000
# time level is  -18
# time is:  2014-06-30T06:00:00.000000000
# time level is  -19
# time is:  2014-06-30T05:00:00.000000000
# time level is  -20
# time is:  2014-06-30T04:00:00.000000000
# time level is  -21
# time is:  2014-06-30T03:00:00.000000000
# time level is  -22
# time is:  2014-06-30T02:00:00.000000000
# time level is  -23
# time is:  2014-06-30T01:00:00.000000000
# time level is  -24
# time is:  2014-06-30T00:00:00.000000000
# time level is  -25
# time is:  2014-06-29T23:00:00.000000000
# time level is  -26
# time is:  2014-06-29T22:00:00.000000000
# time level is  -27
# time is:  2014-06-29T21:00:00.000000000
# time level is  -28
# time is:  2014-06-29T20:00:00.000000000
# time level is  -29
# time is:  2014-06-29T19:00:00.000000000
# time level is  -30
# time is:  2014-06-29T18:00:00.000000000
# time level is  -31
# time is:  2014-06-29T17:00:00.000000000
# time level is  -32
# time is:  2014-06-29T16:00:00.000000000
# time level is  -33
# time is:  2014-06-29T15:00:00.000000000
# time level is  -34
# time is:  2014-06-29T14:00:00.000000000
# time level is  -35
# time is:  2014-06-29T13:00:00.000000000
# time level is  -36
# time is:  2014-06-29T12:00:00.000000000
# time level is  -37
# time is:  2014-06-29T11:00:00.000000000
# time level is  -38
# time is:  2014-06-29T10:00:00.000000000
# time level is  -39
# time is:  2014-06-29T09:00:00.000000000
# time level is  -40
# time is:  2014-06-29T08:00:00.000000000
# time level is  -41
# time is:  2014-06-29T07:00:00.000000000
# time level is  -42
# time is:  2014-06-29T06:00:00.000000000
# time level is  -43
# time is:  2014-06-29T05:00:00.000000000
# time level is  -44
# time is:  2014-06-29T04:00:00.000000000
# time level is  -45
# time is:  2014-06-29T03:00:00.000000000
# time level is  -46
# time is:  2014-06-29T02:00:00.000000000
# time level is  -47
# time is:  2014-06-29T01:00:00.000000000
# time level is  -48
# time is:  2014-06-29T00:00:00.000000000
# time level is  -49
# time is:  2014-06-28T23:00:00.000000000
# time level is  -50
# time is:  2014-06-28T22:00:00.000000000
# time level is  -51
# time is:  2014-06-28T21:00:00.000000000
# time level is  -52
# time is:  2014-06-28T20:00:00.000000000
# time level is  -53
# time is:  2014-06-28T19:00:00.000000000
# time level is  -54
# time is:  2014-06-28T18:00:00.000000000
# time level is  -55
# time is:  2014-06-28T17:00:00.000000000
# time level is  -56
# time is:  2014-06-28T16:00:00.000000000
# time level is  -57
# time is:  2014-06-28T15:00:00.000000000
# time level is  -58
# time is:  2014-06-28T14:00:00.000000000
# time level is  -59
# time is:  2014-06-28T13:00:00.000000000
# time level is  -60
# time is:  2014-06-28T12:00:00.000000000
# time level is  -61
# time is:  2014-06-28T11:00:00.000000000
# time level is  -62
# time is:  2014-06-28T10:00:00.000000000
# time level is  -63
# time is:  2014-06-28T09:00:00.000000000
# time level is  -64
# time is:  2014-06-28T08:00:00.000000000
# time level is  -65
# time is:  2014-06-28T07:00:00.000000000
# time level is  -66
# time is:  2014-06-28T06:00:00.000000000
# time level is  -67
# time is:  2014-06-28T05:00:00.000000000
# time level is  -68
# time is:  2014-06-28T04:00:00.000000000
# time level is  -69
# time is:  2014-06-28T03:00:00.000000000
# time level is  -70
# time is:  2014-06-28T02:00:00.000000000
# time level is  -71
# time is:  2014-06-28T01:00:00.000000000
# time level is  -72
# time is:  2014-06-28T00:00:00.000000000
# time level is  -73
# time is:  2014-06-27T23:00:00.000000000
# time level is  -74
# time is:  2014-06-27T22:00:00.000000000
# time level is  -75
# time is:  2014-06-27T21:00:00.000000000
# time level is  -76
# time is:  2014-06-27T20:00:00.000000000
# time level is  -77
# time is:  2014-06-27T19:00:00.000000000
# time level is  -78
# time is:  2014-06-27T18:00:00.000000000
# time level is  -79
# time is:  2014-06-27T17:00:00.000000000
# time level is  -80
# time is:  2014-06-27T16:00:00.000000000
# time level is  -81
# time is:  2014-06-27T15:00:00.000000000
# time level is  -82
# time is:  2014-06-27T14:00:00.000000000
# time level is  -83
# time is:  2014-06-27T13:00:00.000000000
# time level is  -84
# time is:  2014-06-27T12:00:00.000000000
# time level is  -85
# time is:  2014-06-27T11:00:00.000000000
# time level is  -86
# time is:  2014-06-27T10:00:00.000000000
# time level is  -87
# time is:  2014-06-27T09:00:00.000000000
# time level is  -88
# time is:  2014-06-27T08:00:00.000000000
# time level is  -89
# time is:  2014-06-27T07:00:00.000000000
# time level is  -90
# time is:  2014-06-27T06:00:00.000000000
# time level is  -91
# time is:  2014-06-27T05:00:00.000000000
# time level is  -92
# time is:  2014-06-27T04:00:00.000000000
# time level is  -93
# time is:  2014-06-27T03:00:00.000000000
# time level is  -94
# time is:  2014-06-27T02:00:00.000000000
# time level is  -95
# time is:  2014-06-27T01:00:00.000000000
# time level is  -96
# time is:  2014-06-27T00:00:00.000000000
# time level is  -97
# time is:  2014-06-26T23:00:00.000000000
# time level is  -98
# time is:  2014-06-26T22:00:00.000000000
# time level is  -99
# time is:  2014-06-26T21:00:00.000000000
# time level is  -100
# time is:  2014-06-26T20:00:00.000000000
# time level is  -101
# time is:  2014-06-26T19:00:00.000000000
# time level is  -102
# time is:  2014-06-26T18:00:00.000000000
# time level is  -103
# time is:  2014-06-26T17:00:00.000000000
# time level is  -104
# time is:  2014-06-26T16:00:00.000000000
# time level is  -105
# time is:  2014-06-26T15:00:00.000000000
# time level is  -106
# time is:  2014-06-26T14:00:00.000000000
# time level is  -107
# time is:  2014-06-26T13:00:00.000000000
# time level is  -108
# time is:  2014-06-26T12:00:00.000000000
# time level is  -109
# time is:  2014-06-26T11:00:00.000000000
# time level is  -110
# time is:  2014-06-26T10:00:00.000000000
# time level is  -111
# time is:  2014-06-26T09:00:00.000000000
# time level is  -112
# time is:  2014-06-26T08:00:00.000000000
# time level is  -113
# time is:  2014-06-26T07:00:00.000000000
# time level is  -114
# time is:  2014-06-26T06:00:00.000000000
# time level is  -115
# time is:  2014-06-26T05:00:00.000000000
# time level is  -116
# time is:  2014-06-26T04:00:00.000000000
# time level is  -117
# time is:  2014-06-26T03:00:00.000000000
# time level is  -118
# time is:  2014-06-26T02:00:00.000000000
# time level is  -119
# time is:  2014-06-26T01:00:00.000000000
# time level is  -120
# time is:  2014-06-26T00:00:00.000000000
# time level is  -121
# time is:  2014-06-25T23:00:00.000000000
# time level is  -122
# time is:  2014-06-25T22:00:00.000000000
# time level is  -123
# time is:  2014-06-25T21:00:00.000000000
# time level is  -124
# time is:  2014-06-25T20:00:00.000000000
# time level is  -125
# time is:  2014-06-25T19:00:00.000000000
# time level is  -126
# time is:  2014-06-25T18:00:00.000000000
# time level is  -127
# time is:  2014-06-25T17:00:00.000000000
# time level is  -128
# time is:  2014-06-25T16:00:00.000000000
# time level is  -129
# time is:  2014-06-25T15:00:00.000000000
# time level is  -130
# time is:  2014-06-25T14:00:00.000000000
# time level is  -131
# time is:  2014-06-25T13:00:00.000000000
# time level is  -132
# time is:  2014-06-25T12:00:00.000000000
# time level is  -133
# time is:  2014-06-25T11:00:00.000000000
# time level is  -134
# time is:  2014-06-25T10:00:00.000000000
# time level is  -135
# time is:  2014-06-25T09:00:00.000000000
# time level is  -136
# time is:  2014-06-25T08:00:00.000000000
# time level is  -137
# time is:  2014-06-25T07:00:00.000000000
# time level is  -138
# time is:  2014-06-25T06:00:00.000000000
# time level is  -139
# time is:  2014-06-25T05:00:00.000000000
# time level is  -140
# time is:  2014-06-25T04:00:00.000000000
# time level is  -141
# time is:  2014-06-25T03:00:00.000000000
# time level is  -142
# time is:  2014-06-25T02:00:00.000000000
# time level is  -143
# time is:  2014-06-25T01:00:00.000000000
# time level is  -144
# time is:  2014-06-25T00:00:00.000000000
# time level is  -145
# time is:  2014-06-24T23:00:00.000000000
# time level is  -146
# time is:  2014-06-24T22:00:00.000000000
# time level is  -147
# time is:  2014-06-24T21:00:00.000000000
# time level is  -148
# time is:  2014-06-24T20:00:00.000000000
# time level is  -149
# time is:  2014-06-24T19:00:00.000000000
# time level is  -150
# time is:  2014-06-24T18:00:00.000000000
# time level is  -151
# time is:  2014-06-24T17:00:00.000000000
# time level is  -152
# time is:  2014-06-24T16:00:00.000000000
# time level is  -153
# time is:  2014-06-24T15:00:00.000000000
# time level is  -154
# time is:  2014-06-24T14:00:00.000000000
# time level is  -155
# time is:  2014-06-24T13:00:00.000000000
# time level is  -156
# time is:  2014-06-24T12:00:00.000000000
# time level is  -157
# time is:  2014-06-24T11:00:00.000000000
# time level is  -158
# time is:  2014-06-24T10:00:00.000000000
# time level is  -159
# time is:  2014-06-24T09:00:00.000000000
# time level is  -160
# time is:  2014-06-24T08:00:00.000000000
# time level is  -161
# time is:  2014-06-24T07:00:00.000000000
# time level is  -162
# time is:  2014-06-24T06:00:00.000000000
# time level is  -163
# time is:  2014-06-24T05:00:00.000000000
# time level is  -164
# time is:  2014-06-24T04:00:00.000000000
# time level is  -165
# time is:  2014-06-24T03:00:00.000000000
# time level is  -166
# time is:  2014-06-24T02:00:00.000000000
# time level is  -167
# time is:  2014-06-24T01:00:00.000000000
# time level is  -168
# time is:  2014-06-24T00:00:00.000000000
# time level is  -169
# time is:  2014-06-23T23:00:00.000000000
# time level is  -170
# time is:  2014-06-23T22:00:00.000000000
# time level is  -171
# time is:  2014-06-23T21:00:00.000000000
# time level is  -172
# time is:  2014-06-23T20:00:00.000000000
# time level is  -173
# time is:  2014-06-23T19:00:00.000000000
# time level is  -174
# time is:  2014-06-23T18:00:00.000000000
# time level is  -175
# time is:  2014-06-23T17:00:00.000000000
# time level is  -176
# time is:  2014-06-23T16:00:00.000000000
# time level is  -177
# time is:  2014-06-23T15:00:00.000000000
# time level is  -178
# time is:  2014-06-23T14:00:00.000000000
# time level is  -179
# time is:  2014-06-23T13:00:00.000000000
# time level is  -180
# time is:  2014-06-23T12:00:00.000000000
# time level is  -181
# time is:  2014-06-23T11:00:00.000000000
# time level is  -182
# time is:  2014-06-23T10:00:00.000000000
# time level is  -183
# time is:  2014-06-23T09:00:00.000000000
# time level is  -184
# time is:  2014-06-23T08:00:00.000000000
# time level is  -185
# time is:  2014-06-23T07:00:00.000000000
# time level is  -186
# time is:  2014-06-23T06:00:00.000000000
# time level is  -187
# time is:  2014-06-23T05:00:00.000000000
# time level is  -188
# time is:  2014-06-23T04:00:00.000000000
# time level is  -189
# time is:  2014-06-23T03:00:00.000000000
# time level is  -190
# time is:  2014-06-23T02:00:00.000000000
# time level is  -191
# time is:  2014-06-23T01:00:00.000000000
# time level is  -192
# time is:  2014-06-23T00:00:00.000000000
# time level is  -193
# time is:  2014-06-22T23:00:00.000000000
# time level is  -194
# time is:  2014-06-22T22:00:00.000000000
# time level is  -195
# time is:  2014-06-22T21:00:00.000000000
# time level is  -196
# time is:  2014-06-22T20:00:00.000000000
# time level is  -197
# time is:  2014-06-22T19:00:00.000000000
# time level is  -198
# time is:  2014-06-22T18:00:00.000000000
# time level is  -199
# time is:  2014-06-22T17:00:00.000000000
# time level is  -200
# time is:  2014-06-22T16:00:00.000000000
# time level is  -201
# time is:  2014-06-22T15:00:00.000000000
# time level is  -202
# time is:  2014-06-22T14:00:00.000000000
# time level is  -203
# time is:  2014-06-22T13:00:00.000000000
# time level is  -204
# time is:  2014-06-22T12:00:00.000000000
# time level is  -205
# time is:  2014-06-22T11:00:00.000000000
# time level is  -206
# time is:  2014-06-22T10:00:00.000000000
# time level is  -207
# time is:  2014-06-22T09:00:00.000000000
# time level is  -208
# time is:  2014-06-22T08:00:00.000000000
# time level is  -209
# time is:  2014-06-22T07:00:00.000000000
# time level is  -210
# time is:  2014-06-22T06:00:00.000000000
# time level is  -211
# time is:  2014-06-22T05:00:00.000000000
# time level is  -212
# time is:  2014-06-22T04:00:00.000000000
# time level is  -213
# time is:  2014-06-22T03:00:00.000000000
# time level is  -214
# time is:  2014-06-22T02:00:00.000000000
# time level is  -215
# time is:  2014-06-22T01:00:00.000000000
# time level is  -216
# time is:  2014-06-22T00:00:00.000000000
# time level is  -217
# time is:  2014-06-21T23:00:00.000000000
# time level is  -218
# time is:  2014-06-21T22:00:00.000000000
# time level is  -219
# time is:  2014-06-21T21:00:00.000000000
# time level is  -220
# time is:  2014-06-21T20:00:00.000000000
# time level is  -221
# time is:  2014-06-21T19:00:00.000000000
# time level is  -222
# time is:  2014-06-21T18:00:00.000000000
# time level is  -223
# time is:  2014-06-21T17:00:00.000000000
# time level is  -224
# time is:  2014-06-21T16:00:00.000000000
# time level is  -225
# time is:  2014-06-21T15:00:00.000000000
# time level is  -226
# time is:  2014-06-21T14:00:00.000000000
# time level is  -227
# time is:  2014-06-21T13:00:00.000000000
# time level is  -228
# time is:  2014-06-21T12:00:00.000000000
# time level is  -229
# time is:  2014-06-21T11:00:00.000000000
# time level is  -230
# time is:  2014-06-21T10:00:00.000000000
# time level is  -231
# time is:  2014-06-21T09:00:00.000000000
# time level is  -232
# time is:  2014-06-21T08:00:00.000000000
# time level is  -233
# time is:  2014-06-21T07:00:00.000000000
# time level is  -234
# time is:  2014-06-21T06:00:00.000000000
# time level is  -235
# time is:  2014-06-21T05:00:00.000000000
# time level is  -236
# time is:  2014-06-21T04:00:00.000000000
# time level is  -237
# time is:  2014-06-21T03:00:00.000000000
# time level is  -238
# time is:  2014-06-21T02:00:00.000000000
# time level is  -239
# time is:  2014-06-21T01:00:00.000000000
# time level is  -240
# time is:  2014-06-21T00:00:00.000000000
# time level is  -241
# time is:  2014-06-20T23:00:00.000000000
# time level is  -242
# time is:  2014-06-20T22:00:00.000000000
# time level is  -243
# time is:  2014-06-20T21:00:00.000000000
# time level is  -244
# time is:  2014-06-20T20:00:00.000000000
# time level is  -245
# time is:  2014-06-20T19:00:00.000000000
# time level is  -246
# time is:  2014-06-20T18:00:00.000000000
# time level is  -247
# time is:  2014-06-20T17:00:00.000000000
# time level is  -248
# time is:  2014-06-20T16:00:00.000000000
# time level is  -249
# time is:  2014-06-20T15:00:00.000000000
# time level is  -250
# time is:  2014-06-20T14:00:00.000000000
# time level is  -251
# time is:  2014-06-20T13:00:00.000000000
# time level is  -252
# time is:  2014-06-20T12:00:00.000000000
# time level is  -253
# time is:  2014-06-20T11:00:00.000000000
# time level is  -254
# time is:  2014-06-20T10:00:00.000000000
# time level is  -255
# time is:  2014-06-20T09:00:00.000000000
# time level is  -256
# time is:  2014-06-20T08:00:00.000000000
# time level is  -257
# time is:  2014-06-20T07:00:00.000000000
# time level is  -258
# time is:  2014-06-20T06:00:00.000000000
# time level is  -259
# time is:  2014-06-20T05:00:00.000000000
# time level is  -260
# time is:  2014-06-20T04:00:00.000000000
# time level is  -261
# time is:  2014-06-20T03:00:00.000000000
# time level is  -262
# time is:  2014-06-20T02:00:00.000000000
# time level is  -263
# time is:  2014-06-20T01:00:00.000000000
# time level is  -264
# time is:  2014-06-20T00:00:00.000000000
# time level is  -265
# time is:  2014-06-19T23:00:00.000000000
# time level is  -266
# time is:  2014-06-19T22:00:00.000000000
# time level is  -267
# time is:  2014-06-19T21:00:00.000000000
# time level is  -268
# time is:  2014-06-19T20:00:00.000000000
# time level is  -269
# time is:  2014-06-19T19:00:00.000000000
# time level is  -270
# time is:  2014-06-19T18:00:00.000000000
# time level is  -271
# time is:  2014-06-19T17:00:00.000000000
# time level is  -272
# time is:  2014-06-19T16:00:00.000000000
# time level is  -273
# time is:  2014-06-19T15:00:00.000000000
# time level is  -274
# time is:  2014-06-19T14:00:00.000000000
# time level is  -275
# time is:  2014-06-19T13:00:00.000000000
# time level is  -276
# time is:  2014-06-19T12:00:00.000000000
# time level is  -277
# time is:  2014-06-19T11:00:00.000000000
# time level is  -278
# time is:  2014-06-19T10:00:00.000000000
# time level is  -279
# time is:  2014-06-19T09:00:00.000000000
# time level is  -280
# time is:  2014-06-19T08:00:00.000000000
# time level is  -281
# time is:  2014-06-19T07:00:00.000000000
# time level is  -282
# time is:  2014-06-19T06:00:00.000000000
# time level is  -283
# time is:  2014-06-19T05:00:00.000000000
# time level is  -284
# time is:  2014-06-19T04:00:00.000000000
# time level is  -285
# time is:  2014-06-19T03:00:00.000000000
# time level is  -286
# time is:  2014-06-19T02:00:00.000000000
# time level is  -287
# time is:  2014-06-19T01:00:00.000000000
# time level is  -288
# time is:  2014-06-19T00:00:00.000000000
# time level is  -289
# time is:  2014-06-18T23:00:00.000000000
# time level is  -290
# time is:  2014-06-18T22:00:00.000000000
# time level is  -291
# time is:  2014-06-18T21:00:00.000000000
# time level is  -292
# time is:  2014-06-18T20:00:00.000000000
# time level is  -293
# time is:  2014-06-18T19:00:00.000000000
# time level is  -294
# time is:  2014-06-18T18:00:00.000000000
# time level is  -295
# time is:  2014-06-18T17:00:00.000000000
# time level is  -296
# time is:  2014-06-18T16:00:00.000000000
# time level is  -297
# time is:  2014-06-18T15:00:00.000000000
# time level is  -298
# time is:  2014-06-18T14:00:00.000000000
# time level is  -299
# time is:  2014-06-18T13:00:00.000000000
# time level is  -300
# time is:  2014-06-18T12:00:00.000000000
# time level is  -301
# time is:  2014-06-18T11:00:00.000000000
# time level is  -302
# time is:  2014-06-18T10:00:00.000000000
# time level is  -303
# time is:  2014-06-18T09:00:00.000000000
# time level is  -304
# time is:  2014-06-18T08:00:00.000000000
# time level is  -305
# time is:  2014-06-18T07:00:00.000000000
# time level is  -306
# time is:  2014-06-18T06:00:00.000000000
# time level is  -307
# time is:  2014-06-18T05:00:00.000000000
# time level is  -308
# time is:  2014-06-18T04:00:00.000000000
# time level is  -309
# time is:  2014-06-18T03:00:00.000000000
# time level is  -310
# time is:  2014-06-18T02:00:00.000000000
# time level is  -311
# time is:  2014-06-18T01:00:00.000000000
# time level is  -312
# time is:  2014-06-18T00:00:00.000000000
# time level is  -313
# time is:  2014-06-17T23:00:00.000000000
# time level is  -314
# time is:  2014-06-17T22:00:00.000000000
# time level is  -315
# time is:  2014-06-17T21:00:00.000000000
# time level is  -316
# time is:  2014-06-17T20:00:00.000000000
# time level is  -317
# time is:  2014-06-17T19:00:00.000000000
# time level is  -318
# time is:  2014-06-17T18:00:00.000000000
# time level is  -319
# time is:  2014-06-17T17:00:00.000000000
# time level is  -320
# time is:  2014-06-17T16:00:00.000000000
# time level is  -321
# time is:  2014-06-17T15:00:00.000000000
# time level is  -322
# time is:  2014-06-17T14:00:00.000000000
# time level is  -323
# time is:  2014-06-17T13:00:00.000000000
# time level is  -324
# time is:  2014-06-17T12:00:00.000000000
# time level is  -325
# time is:  2014-06-17T11:00:00.000000000
# time level is  -326
# time is:  2014-06-17T10:00:00.000000000
# time level is  -327
# time is:  2014-06-17T09:00:00.000000000
# time level is  -328
# time is:  2014-06-17T08:00:00.000000000
# time level is  -329
# time is:  2014-06-17T07:00:00.000000000
# time level is  -330
# time is:  2014-06-17T06:00:00.000000000
# time level is  -331
# time is:  2014-06-17T05:00:00.000000000
# time level is  -332
# time is:  2014-06-17T04:00:00.000000000
# time level is  -333
# time is:  2014-06-17T03:00:00.000000000
# time level is  -334
# time is:  2014-06-17T02:00:00.000000000
# time level is  -335
# time is:  2014-06-17T01:00:00.000000000
# time level is  -336
# time is:  2014-06-17T00:00:00.000000000
# time level is  -337
# time is:  2014-06-16T23:00:00.000000000
# time level is  -338
# time is:  2014-06-16T22:00:00.000000000
# time level is  -339
# time is:  2014-06-16T21:00:00.000000000
# time level is  -340
# time is:  2014-06-16T20:00:00.000000000
# time level is  -341
# time is:  2014-06-16T19:00:00.000000000
# time level is  -342
# time is:  2014-06-16T18:00:00.000000000
# time level is  -343
# time is:  2014-06-16T17:00:00.000000000
# time level is  -344
# time is:  2014-06-16T16:00:00.000000000
# time level is  -345
# time is:  2014-06-16T15:00:00.000000000
# time level is  -346
# time is:  2014-06-16T14:00:00.000000000
# time level is  -347
# time is:  2014-06-16T13:00:00.000000000
# time level is  -348
# time is:  2014-06-16T12:00:00.000000000
# time level is  -349
# time is:  2014-06-16T11:00:00.000000000
# time level is  -350
# time is:  2014-06-16T10:00:00.000000000
# time level is  -351
# time is:  2014-06-16T09:00:00.000000000
# time level is  -352
# time is:  2014-06-16T08:00:00.000000000
# time level is  -353
# time is:  2014-06-16T07:00:00.000000000
# time level is  -354
# time is:  2014-06-16T06:00:00.000000000
# time level is  -355
# time is:  2014-06-16T05:00:00.000000000
# time level is  -356
# time is:  2014-06-16T04:00:00.000000000
# time level is  -357
# time is:  2014-06-16T03:00:00.000000000
# time level is  -358
# time is:  2014-06-16T02:00:00.000000000
# time level is  -359
# time is:  2014-06-16T01:00:00.000000000
# time level is  -360
# time is:  2014-06-16T00:00:00.000000000
# time level is  -361
# time is:  2014-06-15T23:00:00.000000000
# time level is  -362
# time is:  2014-06-15T22:00:00.000000000
# time level is  -363
# time is:  2014-06-15T21:00:00.000000000
# time level is  -364
# time is:  2014-06-15T20:00:00.000000000
# time level is  -365
# time is:  2014-06-15T19:00:00.000000000
# time level is  -366
# time is:  2014-06-15T18:00:00.000000000
# time level is  -367
# time is:  2014-06-15T17:00:00.000000000
# time level is  -368
# time is:  2014-06-15T16:00:00.000000000
# time level is  -369
# time is:  2014-06-15T15:00:00.000000000
# time level is  -370
# time is:  2014-06-15T14:00:00.000000000
# time level is  -371
# time is:  2014-06-15T13:00:00.000000000
# time level is  -372
# time is:  2014-06-15T12:00:00.000000000
# time level is  -373
# time is:  2014-06-15T11:00:00.000000000
# time level is  -374
# time is:  2014-06-15T10:00:00.000000000
# time level is  -375
# time is:  2014-06-15T09:00:00.000000000
# time level is  -376
# time is:  2014-06-15T08:00:00.000000000
# time level is  -377
# time is:  2014-06-15T07:00:00.000000000
# time level is  -378
# time is:  2014-06-15T06:00:00.000000000
# time level is  -379
# time is:  2014-06-15T05:00:00.000000000
# time level is  -380
# time is:  2014-06-15T04:00:00.000000000
# time level is  -381
# time is:  2014-06-15T03:00:00.000000000
# time level is  -382
# time is:  2014-06-15T02:00:00.000000000
# time level is  -383
# time is:  2014-06-15T01:00:00.000000000
# time level is  -384
# time is:  2014-06-15T00:00:00.000000000
# time level is  -385
# time is:  2014-06-14T23:00:00.000000000
# time level is  -386
# time is:  2014-06-14T22:00:00.000000000
# time level is  -387
# time is:  2014-06-14T21:00:00.000000000
# time level is  -388
# time is:  2014-06-14T20:00:00.000000000
# time level is  -389
# time is:  2014-06-14T19:00:00.000000000
# time level is  -390
# time is:  2014-06-14T18:00:00.000000000
# time level is  -391
# time is:  2014-06-14T17:00:00.000000000
# time level is  -392
# time is:  2014-06-14T16:00:00.000000000
# time level is  -393
# time is:  2014-06-14T15:00:00.000000000
# time level is  -394
# time is:  2014-06-14T14:00:00.000000000
# time level is  -395
# time is:  2014-06-14T13:00:00.000000000
# time level is  -396
# time is:  2014-06-14T12:00:00.000000000
# time level is  -397
# time is:  2014-06-14T11:00:00.000000000
# time level is  -398
# time is:  2014-06-14T10:00:00.000000000
# time level is  -399
# time is:  2014-06-14T09:00:00.000000000
# time level is  -400
# time is:  2014-06-14T08:00:00.000000000
# time level is  -401
# time is:  2014-06-14T07:00:00.000000000
# time level is  -402
# time is:  2014-06-14T06:00:00.000000000
# time level is  -403
# time is:  2014-06-14T05:00:00.000000000
# time level is  -404
# time is:  2014-06-14T04:00:00.000000000
# time level is  -405
# time is:  2014-06-14T03:00:00.000000000
# time level is  -406
# time is:  2014-06-14T02:00:00.000000000
# time level is  -407
# time is:  2014-06-14T01:00:00.000000000
# time level is  -408
# time is:  2014-06-14T00:00:00.000000000
# time level is  -409
# time is:  2014-06-13T23:00:00.000000000
# time level is  -410
# time is:  2014-06-13T22:00:00.000000000
# time level is  -411
# time is:  2014-06-13T21:00:00.000000000
# time level is  -412
# time is:  2014-06-13T20:00:00.000000000
# time level is  -413
# time is:  2014-06-13T19:00:00.000000000
# time level is  -414
# time is:  2014-06-13T18:00:00.000000000
# time level is  -415
# time is:  2014-06-13T17:00:00.000000000
# time level is  -416
# time is:  2014-06-13T16:00:00.000000000
# time level is  -417
# time is:  2014-06-13T15:00:00.000000000
# time level is  -418
# time is:  2014-06-13T14:00:00.000000000
# time level is  -419
# time is:  2014-06-13T13:00:00.000000000
# time level is  -420
# time is:  2014-06-13T12:00:00.000000000
# time level is  -421
# time is:  2014-06-13T11:00:00.000000000
# time level is  -422
# time is:  2014-06-13T10:00:00.000000000
# time level is  -423
# time is:  2014-06-13T09:00:00.000000000
# time level is  -424
# time is:  2014-06-13T08:00:00.000000000
# time level is  -425
# time is:  2014-06-13T07:00:00.000000000
# time level is  -426
# time is:  2014-06-13T06:00:00.000000000
# time level is  -427
# time is:  2014-06-13T05:00:00.000000000
# time level is  -428
# time is:  2014-06-13T04:00:00.000000000
# time level is  -429
# time is:  2014-06-13T03:00:00.000000000
# time level is  -430
# time is:  2014-06-13T02:00:00.000000000
# time level is  -431
# time is:  2014-06-13T01:00:00.000000000
# time level is  -432
# time is:  2014-06-13T00:00:00.000000000
# time level is  -433
# time is:  2014-06-12T23:00:00.000000000
# time level is  -434
# time is:  2014-06-12T22:00:00.000000000
# time level is  -435
# time is:  2014-06-12T21:00:00.000000000
# time level is  -436
# time is:  2014-06-12T20:00:00.000000000
# time level is  -437
# time is:  2014-06-12T19:00:00.000000000
# time level is  -438
# time is:  2014-06-12T18:00:00.000000000
# time level is  -439
# time is:  2014-06-12T17:00:00.000000000
# time level is  -440
# time is:  2014-06-12T16:00:00.000000000
# time level is  -441
# time is:  2014-06-12T15:00:00.000000000
# time level is  -442
# time is:  2014-06-12T14:00:00.000000000
# time level is  -443
# time is:  2014-06-12T13:00:00.000000000
# time level is  -444
# time is:  2014-06-12T12:00:00.000000000
# time level is  -445
# time is:  2014-06-12T11:00:00.000000000
# time level is  -446
# time is:  2014-06-12T10:00:00.000000000
# time level is  -447
# time is:  2014-06-12T09:00:00.000000000
# time level is  -448
# time is:  2014-06-12T08:00:00.000000000
# time level is  -449
# time is:  2014-06-12T07:00:00.000000000
# time level is  -450
# time is:  2014-06-12T06:00:00.000000000
# time level is  -451
# time is:  2014-06-12T05:00:00.000000000
# time level is  -452
# time is:  2014-06-12T04:00:00.000000000
# time level is  -453
# time is:  2014-06-12T03:00:00.000000000
# time level is  -454
# time is:  2014-06-12T02:00:00.000000000
# time level is  -455
# time is:  2014-06-12T01:00:00.000000000
# time level is  -456
# time is:  2014-06-12T00:00:00.000000000
# time level is  -457
# time is:  2014-06-11T23:00:00.000000000
# time level is  -458
# time is:  2014-06-11T22:00:00.000000000
# time level is  -459
# time is:  2014-06-11T21:00:00.000000000
# time level is  -460
# time is:  2014-06-11T20:00:00.000000000
# time level is  -461
# time is:  2014-06-11T19:00:00.000000000
# time level is  -462
# time is:  2014-06-11T18:00:00.000000000
# time level is  -463
# time is:  2014-06-11T17:00:00.000000000
# time level is  -464
# time is:  2014-06-11T16:00:00.000000000
# time level is  -465
# time is:  2014-06-11T15:00:00.000000000
# time level is  -466
# time is:  2014-06-11T14:00:00.000000000
# time level is  -467
# time is:  2014-06-11T13:00:00.000000000
# time level is  -468
# time is:  2014-06-11T12:00:00.000000000
# time level is  -469
# time is:  2014-06-11T11:00:00.000000000
# time level is  -470
# time is:  2014-06-11T10:00:00.000000000
# time level is  -471
# time is:  2014-06-11T09:00:00.000000000
# time level is  -472
# time is:  2014-06-11T08:00:00.000000000
# time level is  -473
# time is:  2014-06-11T07:00:00.000000000
# time level is  -474
# time is:  2014-06-11T06:00:00.000000000
# time level is  -475
# time is:  2014-06-11T05:00:00.000000000
# time level is  -476
# time is:  2014-06-11T04:00:00.000000000
# time level is  -477
# time is:  2014-06-11T03:00:00.000000000
# time level is  -478
# time is:  2014-06-11T02:00:00.000000000
# time level is  -479
# time is:  2014-06-11T01:00:00.000000000
# time level is  -480
# time is:  2014-06-11T00:00:00.000000000
# time level is  -481
# time is:  2014-06-10T23:00:00.000000000
# time level is  -482
# time is:  2014-06-10T22:00:00.000000000
# time level is  -483
# time is:  2014-06-10T21:00:00.000000000
# time level is  -484
# time is:  2014-06-10T20:00:00.000000000
# time level is  -485
# time is:  2014-06-10T19:00:00.000000000
# time level is  -486
# time is:  2014-06-10T18:00:00.000000000
# time level is  -487
# time is:  2014-06-10T17:00:00.000000000
# time level is  -488
# time is:  2014-06-10T16:00:00.000000000
# time level is  -489
# time is:  2014-06-10T15:00:00.000000000
# time level is  -490
# time is:  2014-06-10T14:00:00.000000000
# time level is  -491
# time is:  2014-06-10T13:00:00.000000000
# time level is  -492
# time is:  2014-06-10T12:00:00.000000000
# time level is  -493
# time is:  2014-06-10T11:00:00.000000000
# time level is  -494
# time is:  2014-06-10T10:00:00.000000000
# time level is  -495
# time is:  2014-06-10T09:00:00.000000000
# time level is  -496
# time is:  2014-06-10T08:00:00.000000000
# time level is  -497
# time is:  2014-06-10T07:00:00.000000000
# time level is  -498
# time is:  2014-06-10T06:00:00.000000000
# time level is  -499
# time is:  2014-06-10T05:00:00.000000000
# time level is  -500
# time is:  2014-06-10T04:00:00.000000000
# time level is  -501
# time is:  2014-06-10T03:00:00.000000000
# time level is  -502
# time is:  2014-06-10T02:00:00.000000000
# time level is  -503
# time is:  2014-06-10T01:00:00.000000000
# time level is  -504
# time is:  2014-06-10T00:00:00.000000000
# time level is  -505
# time is:  2014-06-09T23:00:00.000000000
# time level is  -506
# time is:  2014-06-09T22:00:00.000000000
# time level is  -507
# time is:  2014-06-09T21:00:00.000000000
# time level is  -508
# time is:  2014-06-09T20:00:00.000000000
# time level is  -509
# time is:  2014-06-09T19:00:00.000000000
# time level is  -510
# time is:  2014-06-09T18:00:00.000000000
# time level is  -511
# time is:  2014-06-09T17:00:00.000000000
# time level is  -512
# time is:  2014-06-09T16:00:00.000000000
# time level is  -513
# time is:  2014-06-09T15:00:00.000000000
# time level is  -514
# time is:  2014-06-09T14:00:00.000000000
# time level is  -515
# time is:  2014-06-09T13:00:00.000000000
# time level is  -516
# time is:  2014-06-09T12:00:00.000000000
# time level is  -517
# time is:  2014-06-09T11:00:00.000000000
# time level is  -518
# time is:  2014-06-09T10:00:00.000000000
# time level is  -519
# time is:  2014-06-09T09:00:00.000000000
# time level is  -520
# time is:  2014-06-09T08:00:00.000000000
# time level is  -521
# time is:  2014-06-09T07:00:00.000000000
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_09_07_lat4p676N = gdf_newccvl.to_frame().T
# time level is  -522
# time is:  2014-06-09T06:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_09_07_lat4p676N).to_file("2014_06_09_07_lat4p676N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_09_07_lat4p676N.copy()
# command3:  del(ccvl_2014_06_09_07_lat4p676N)
# time level is  -523
# time is:  2014-06-09T05:00:00.000000000
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_09_05_lat4p555N = gdf_newccvl.to_frame().T
# time level is  -524
# time is:  2014-06-09T04:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_09_05_lat4p555N).to_file("2014_06_09_05_lat4p555N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_09_05_lat4p555N.copy()
# command3:  del(ccvl_2014_06_09_05_lat4p555N)
# time level is  -525
# time is:  2014-06-09T03:00:00.000000000
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_09_03_lat4p377N = gdf_newccvl.to_frame().T
# time level is  -526
# time is:  2014-06-09T02:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_09_03_lat4p377N).to_file("2014_06_09_03_lat4p377N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_09_03_lat4p377N.copy()
# command3:  del(ccvl_2014_06_09_03_lat4p377N)
# time level is  -527
# time is:  2014-06-09T01:00:00.000000000
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_09_01_lat4p387N = gdf_newccvl.to_frame().T
# time level is  -528
# time is:  2014-06-09T00:00:00.000000000
# Step 3 appending:  ccvl_2014_06_09_01_lat4p387N = ccvl_2014_06_09_01_lat4p387N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -529
# time is:  2014-06-08T23:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_09_01_lat4p387N).to_file("2014_06_09_01_lat4p387N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_09_01_lat4p387N.copy()
# command3:  del(ccvl_2014_06_09_01_lat4p387N)
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_08_23_lat4p378N = gdf_newccvl.to_frame().T
# time level is  -530
# time is:  2014-06-08T22:00:00.000000000
# Step 3 appending:  ccvl_2014_06_08_23_lat4p378N = ccvl_2014_06_08_23_lat4p378N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -531
# time is:  2014-06-08T21:00:00.000000000
# Step 3 appending:  ccvl_2014_06_08_23_lat4p378N = ccvl_2014_06_08_23_lat4p378N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -532
# time is:  2014-06-08T20:00:00.000000000
# Step 3 appending:  ccvl_2014_06_08_23_lat4p378N = ccvl_2014_06_08_23_lat4p378N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -533
# time is:  2014-06-08T19:00:00.000000000
# Step 3 appending:  ccvl_2014_06_08_23_lat4p378N = ccvl_2014_06_08_23_lat4p378N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -534
# time is:  2014-06-08T18:00:00.000000000
# Step 3 appending:  ccvl_2014_06_08_23_lat4p378N = ccvl_2014_06_08_23_lat4p378N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -535
# time is:  2014-06-08T17:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_08_23_lat4p378N).to_file("2014_06_08_23_lat4p378N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_08_23_lat4p378N.copy()
# command3:  del(ccvl_2014_06_08_23_lat4p378N)
# time level is  -536
# time is:  2014-06-08T16:00:00.000000000
# time level is  -537
# time is:  2014-06-08T15:00:00.000000000
# time level is  -538
# time is:  2014-06-08T14:00:00.000000000
# time level is  -539
# time is:  2014-06-08T13:00:00.000000000
# time level is  -540
# time is:  2014-06-08T12:00:00.000000000
# time level is  -541
# time is:  2014-06-08T11:00:00.000000000
# time level is  -542
# time is:  2014-06-08T10:00:00.000000000
# time level is  -543
# time is:  2014-06-08T09:00:00.000000000
# time level is  -544
# time is:  2014-06-08T08:00:00.000000000
# time level is  -545
# time is:  2014-06-08T07:00:00.000000000
# time level is  -546
# time is:  2014-06-08T06:00:00.000000000
# time level is  -547
# time is:  2014-06-08T05:00:00.000000000
# time level is  -548
# time is:  2014-06-08T04:00:00.000000000
# time level is  -549
# time is:  2014-06-08T03:00:00.000000000
# time level is  -550
# time is:  2014-06-08T02:00:00.000000000
# time level is  -551
# time is:  2014-06-08T01:00:00.000000000
# time level is  -552
# time is:  2014-06-08T00:00:00.000000000
# time level is  -553
# time is:  2014-06-07T23:00:00.000000000
# time level is  -554
# time is:  2014-06-07T22:00:00.000000000
# time level is  -555
# time is:  2014-06-07T21:00:00.000000000
# time level is  -556
# time is:  2014-06-07T20:00:00.000000000
# time level is  -557
# time is:  2014-06-07T19:00:00.000000000
# time level is  -558
# time is:  2014-06-07T18:00:00.000000000
# time level is  -559
# time is:  2014-06-07T17:00:00.000000000
# time level is  -560
# time is:  2014-06-07T16:00:00.000000000
# time level is  -561
# time is:  2014-06-07T15:00:00.000000000
# time level is  -562
# time is:  2014-06-07T14:00:00.000000000
# time level is  -563
# time is:  2014-06-07T13:00:00.000000000
# time level is  -564
# time is:  2014-06-07T12:00:00.000000000
# time level is  -565
# time is:  2014-06-07T11:00:00.000000000
# time level is  -566
# time is:  2014-06-07T10:00:00.000000000
# time level is  -567
# time is:  2014-06-07T09:00:00.000000000
# time level is  -568
# time is:  2014-06-07T08:00:00.000000000
# time level is  -569
# time is:  2014-06-07T07:00:00.000000000
# time level is  -570
# time is:  2014-06-07T06:00:00.000000000
# time level is  -571
# time is:  2014-06-07T05:00:00.000000000
# time level is  -572
# time is:  2014-06-07T04:00:00.000000000
# time level is  -573
# time is:  2014-06-07T03:00:00.000000000
# time level is  -574
# time is:  2014-06-07T02:00:00.000000000
# time level is  -575
# time is:  2014-06-07T01:00:00.000000000
# time level is  -576
# time is:  2014-06-07T00:00:00.000000000
# time level is  -577
# time is:  2014-06-06T23:00:00.000000000
# time level is  -578
# time is:  2014-06-06T22:00:00.000000000
# time level is  -579
# time is:  2014-06-06T21:00:00.000000000
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_06_21_lat7p639N = gdf_newccvl.to_frame().T
# time level is  -580
# time is:  2014-06-06T20:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_21_lat7p639N = ccvl_2014_06_06_21_lat7p639N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -581
# time is:  2014-06-06T19:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_21_lat7p639N = ccvl_2014_06_06_21_lat7p639N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -582
# time is:  2014-06-06T18:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_21_lat7p639N = ccvl_2014_06_06_21_lat7p639N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -583
# time is:  2014-06-06T17:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_21_lat7p639N = ccvl_2014_06_06_21_lat7p639N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -584
# time is:  2014-06-06T16:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_21_lat7p639N = ccvl_2014_06_06_21_lat7p639N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -585
# time is:  2014-06-06T15:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_06_21_lat7p639N).to_file("2014_06_06_21_lat7p639N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_06_21_lat7p639N.copy()
# command3:  del(ccvl_2014_06_06_21_lat7p639N)
# time level is  -586
# time is:  2014-06-06T14:00:00.000000000
# time level is  -587
# time is:  2014-06-06T13:00:00.000000000
# time level is  -588
# time is:  2014-06-06T12:00:00.000000000
# time level is  -589
# time is:  2014-06-06T11:00:00.000000000
# time level is  -590
# time is:  2014-06-06T10:00:00.000000000
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_06_10_lat4p328N = gdf_newccvl.to_frame().T
# time level is  -591
# time is:  2014-06-06T09:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_10_lat4p328N = ccvl_2014_06_06_10_lat4p328N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -592
# time is:  2014-06-06T08:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_06_10_lat4p328N).to_file("2014_06_06_10_lat4p328N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_06_10_lat4p328N.copy()
# command3:  del(ccvl_2014_06_06_10_lat4p328N)
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_06_08_lat8p209N = gdf_newccvl.to_frame().T
# time level is  -593
# time is:  2014-06-06T07:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_06_08_lat8p209N).to_file("2014_06_06_08_lat8p209N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_06_08_lat8p209N.copy()
# command3:  del(ccvl_2014_06_06_08_lat8p209N)
# time level is  -594
# time is:  2014-06-06T06:00:00.000000000
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_06_06_lat7p957N = gdf_newccvl.to_frame().T
# time level is  -595
# time is:  2014-06-06T05:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_06_lat7p957N = ccvl_2014_06_06_06_lat7p957N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -596
# time is:  2014-06-06T04:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_06_lat7p957N = ccvl_2014_06_06_06_lat7p957N.append(gdf_ccvls_now.iloc[0:1])
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_06_04_lat7p698N = gdf_newccvl.to_frame().T
# time level is  -597
# time is:  2014-06-06T03:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_06_lat7p957N = ccvl_2014_06_06_06_lat7p957N.append(gdf_ccvls_now.iloc[0:1])
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_06_04_lat7p698N).to_file("2014_06_06_04_lat7p698N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_06_04_lat7p698N.copy()
# command3:  del(ccvl_2014_06_06_04_lat7p698N)
# time level is  -598
# time is:  2014-06-06T02:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_06_lat7p957N = ccvl_2014_06_06_06_lat7p957N.append(gdf_ccvls_now.iloc[0:1])
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_06_02_lat7p578N = gdf_newccvl.to_frame().T
# time level is  -599
# time is:  2014-06-06T01:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_02_lat7p578N = ccvl_2014_06_06_02_lat7p578N.append(gdf_ccvls_now.iloc[0:1])
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_06_06_lat7p957N).to_file("2014_06_06_06_lat7p957N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_06_06_lat7p957N.copy()
# command3:  del(ccvl_2014_06_06_06_lat7p957N)
# time level is  -600
# time is:  2014-06-06T00:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_02_lat7p578N = ccvl_2014_06_06_02_lat7p578N.append(gdf_ccvls_now.iloc[0:1])
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_06_00_lat7p367N = gdf_newccvl.to_frame().T
# time level is  -601
# time is:  2014-06-05T23:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_02_lat7p578N = ccvl_2014_06_06_02_lat7p578N.append(gdf_ccvls_now.iloc[0:1])
# Step 3 appending:  ccvl_2014_06_06_02_lat7p578N = ccvl_2014_06_06_02_lat7p578N.append(gdf_ccvls_now.iloc[1:2])
# Step 3 appending:  ccvl_2014_06_06_00_lat7p367N = ccvl_2014_06_06_00_lat7p367N.append(gdf_ccvls_now.iloc[2:3])
# time level is  -602
# time is:  2014-06-05T22:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_00_lat7p367N = ccvl_2014_06_06_00_lat7p367N.append(gdf_ccvls_now.iloc[0:1])
# time level is  -603
# time is:  2014-06-05T21:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_00_lat7p367N = ccvl_2014_06_06_00_lat7p367N.append(gdf_ccvls_now.iloc[0:1])
# adding new ccvl:  3
# creating gdf:  ccvl_2014_06_05_21_lat7p756N = gdf_newccvl.to_frame().T
# time level is  -604
# time is:  2014-06-05T20:00:00.000000000
# Step 3 appending:  ccvl_2014_06_06_00_lat7p367N = ccvl_2014_06_06_00_lat7p367N.append(gdf_ccvls_now.iloc[0:1])
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_21_lat7p756N).to_file("2014_06_05_21_lat7p756N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_21_lat7p756N.copy()
# command3:  del(ccvl_2014_06_05_21_lat7p756N)
# time level is  -605
# time is:  2014-06-05T19:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_06_00_lat7p367N).to_file("2014_06_06_00_lat7p367N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_06_00_lat7p367N.copy()
# command3:  del(ccvl_2014_06_06_00_lat7p367N)
# adding new ccvl:  2
# creating gdf:  ccvl_2014_06_05_19_lat7p809N = gdf_newccvl.to_frame().T
# time level is  -606
# time is:  2014-06-05T18:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_19_lat7p809N).to_file("2014_06_05_19_lat7p809N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_19_lat7p809N.copy()
# command3:  del(ccvl_2014_06_05_19_lat7p809N)
# time level is  -607
# time is:  2014-06-05T17:00:00.000000000
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_05_17_lat7p902N = gdf_newccvl.to_frame().T
# time level is  -608
# time is:  2014-06-05T16:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_17_lat7p902N).to_file("2014_06_05_17_lat7p902N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_17_lat7p902N.copy()
# command3:  del(ccvl_2014_06_05_17_lat7p902N)
# time level is  -609
# time is:  2014-06-05T15:00:00.000000000
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_05_15_lat7p961N = gdf_newccvl.to_frame().T
# time level is  -610
# time is:  2014-06-05T14:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_15_lat7p961N).to_file("2014_06_05_15_lat7p961N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_15_lat7p961N.copy()
# command3:  del(ccvl_2014_06_05_15_lat7p961N)
# time level is  -611
# time is:  2014-06-05T13:00:00.000000000
# adding new ccvl:  3
# creating gdf:  ccvl_2014_06_05_13_lat7p922N = gdf_newccvl.to_frame().T
# time level is  -612
# time is:  2014-06-05T12:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_13_lat7p922N).to_file("2014_06_05_13_lat7p922N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_13_lat7p922N.copy()
# command3:  del(ccvl_2014_06_05_13_lat7p922N)
# time level is  -613
# time is:  2014-06-05T11:00:00.000000000
# adding new ccvl:  2
# creating gdf:  ccvl_2014_06_05_11_lat7p933N = gdf_newccvl.to_frame().T
# time level is  -614
# time is:  2014-06-05T10:00:00.000000000
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_11_lat7p933N).to_file("2014_06_05_11_lat7p933N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_11_lat7p933N.copy()
# command3:  del(ccvl_2014_06_05_11_lat7p933N)
# adding new ccvl:  5
# creating gdf:  ccvl_2014_06_05_10_lat1p100S = gdf_newccvl.to_frame().T
# time level is  -615
# time is:  2014-06-05T09:00:00.000000000
# Step 3 appending:  ccvl_2014_06_05_10_lat1p100S = ccvl_2014_06_05_10_lat1p100S.append(gdf_ccvls_now.iloc[0:1])
# adding new ccvl:  3
# creating gdf:  ccvl_2014_06_05_09_lat7p900N = gdf_newccvl.to_frame().T
# time level is  -616
# time is:  2014-06-05T08:00:00.000000000
# Step 3 appending:  ccvl_2014_06_05_10_lat1p100S = ccvl_2014_06_05_10_lat1p100S.append(gdf_ccvls_now.iloc[0:1])
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_09_lat7p900N).to_file("2014_06_05_09_lat7p900N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_09_lat7p900N.copy()
# command3:  del(ccvl_2014_06_05_09_lat7p900N)
# time level is  -617
# time is:  2014-06-05T07:00:00.000000000
# Step 3 appending:  ccvl_2014_06_05_10_lat1p100S = ccvl_2014_06_05_10_lat1p100S.append(gdf_ccvls_now.iloc[0:1])
# adding new ccvl:  3
# creating gdf:  ccvl_2014_06_05_07_lat7p746N = gdf_newccvl.to_frame().T
# time level is  -618
# time is:  2014-06-05T06:00:00.000000000
# Step 3 appending:  ccvl_2014_06_05_10_lat1p100S = ccvl_2014_06_05_10_lat1p100S.append(gdf_ccvls_now.iloc[0:1])
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_07_lat7p746N).to_file("2014_06_05_07_lat7p746N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_07_lat7p746N.copy()
# command3:  del(ccvl_2014_06_05_07_lat7p746N)
# time level is  -619
# time is:  2014-06-05T05:00:00.000000000
# Step 3 appending:  ccvl_2014_06_05_10_lat1p100S = ccvl_2014_06_05_10_lat1p100S.append(gdf_ccvls_now.iloc[0:1])
# adding new ccvl:  1
# creating gdf:  ccvl_2014_06_05_05_lat4p958N = gdf_newccvl.to_frame().T
# time level is  -620
# time is:  2014-06-05T04:00:00.000000000
# Step 3 appending:  ccvl_2014_06_05_10_lat1p100S = ccvl_2014_06_05_10_lat1p100S.append(gdf_ccvls_now.iloc[0:1])
# orphan, terminate. command:  gp.GeoDataFrame(ccvl_2014_06_05_05_lat4p958N).to_file("2014_06_05_05_lat4p958N.geojson", driver="GeoJSON")
# command2:  dummy = ccvl_2014_06_05_05_lat4p958N.copy()
# command3:  del(ccvl_2014_06_05_05_lat4p958N)
# time level is  -621
# time is:  2014-06-05T03:00:00.000000000
# Step 3 appending:  ccvl_2014_06_05_10_lat1p100S = ccvl_2014_06_05_10_lat1p100S.append(gdf_ccvls_now.iloc[0:1])
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_05_03_lat4p610N = gdf_newccvl.to_frame().T
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_05_03_lat4p610N = gdf_newccvl.to_frame().T
# time level is  -622
# time is:  2014-06-05T02:00:00.000000000
# Step 3 appending:  ccvl_2014_06_05_10_lat1p100S = ccvl_2014_06_05_10_lat1p100S.append(gdf_ccvls_now.iloc[0:1])
# Step 3 appending:  ccvl_2014_06_05_03_lat4p610N = ccvl_2014_06_05_03_lat4p610N.append(gdf_ccvls_now.iloc[1:2])
# Step 3 appending:  ccvl_2014_06_05_03_lat4p610N = ccvl_2014_06_05_03_lat4p610N.append(gdf_ccvls_now.iloc[2:3])
# time level is  -623
# time is:  2014-06-05T01:00:00.000000000
# ...
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[102:103])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[103:104])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[104:105])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[105:106])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[106:107])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[107:108])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[108:109])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[109:110])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[110:111])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[111:112])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[112:113])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[113:114])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[114:115])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[115:116])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[116:117])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[117:118])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[118:119])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[119:120])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[120:121])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[121:122])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[122:123])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[123:124])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[124:125])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[125:126])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[126:127])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[127:128])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[128:129])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[129:130])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[130:131])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[131:132])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[132:133])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[133:134])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[134:135])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[135:136])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[136:137])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[137:138])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[138:139])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[139:140])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[140:141])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[141:142])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[142:143])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[143:144])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[144:145])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[145:146])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[146:147])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[147:148])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[148:149])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[149:150])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[150:151])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[151:152])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[152:153])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[153:154])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[154:155])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[155:156])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[156:157])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[157:158])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[158:159])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[159:160])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[160:161])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[161:162])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[162:163])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[163:164])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[164:165])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[165:166])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[166:167])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[167:168])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[168:169])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[169:170])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[170:171])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[171:172])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[172:173])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[173:174])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[174:175])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[175:176])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[176:177])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[177:178])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[178:179])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[179:180])
# time level is  -720
# time is:  2014-06-01T00:00:00.000000000
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[0:1])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[1:2])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[2:3])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[3:4])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[4:5])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[5:6])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[6:7])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[7:8])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[8:9])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[9:10])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[10:11])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[11:12])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[12:13])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[13:14])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[14:15])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[15:16])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[16:17])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[17:18])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[18:19])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[19:20])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[20:21])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[21:22])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[22:23])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[23:24])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[24:25])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[25:26])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[26:27])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[27:28])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[28:29])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[29:30])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[30:31])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[31:32])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[32:33])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[33:34])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[34:35])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[35:36])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[36:37])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[37:38])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[38:39])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[39:40])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[40:41])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[41:42])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[42:43])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[43:44])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[44:45])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[45:46])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[46:47])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[47:48])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[48:49])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[49:50])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[50:51])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[51:52])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[52:53])
# Step 3 appending:  ccvl_2014_06_04_16_lat3p897N = ccvl_2014_06_04_16_lat3p897N.append(gdf_ccvls_now.iloc[53:54])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[54:55])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[55:56])
# Step 3 appending:  ccvl_2014_06_03_18_lat5p399N = ccvl_2014_06_03_18_lat5p399N.append(gdf_ccvls_now.iloc[56:57])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[57:58])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[58:59])
# Step 3 appending:  ccvl_2014_06_03_09_lat1p475N = ccvl_2014_06_03_09_lat1p475N.append(gdf_ccvls_now.iloc[59:60])
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_01_00_lat0p533N = gdf_newccvl.to_frame().T
# adding new ccvl:  0
# creating gdf:  ccvl_2014_06_01_00_lat0p533N = gdf_newccvl.to_frame().T

# %%
gf = gp.read_file('2014_06_03_05_lat4p684N.geojson')
gf
# Out:
#   tqv_values               area             maxlon                 time  \
# 0         55  566.5040291398436                 90  2014-06-03T05:00:00
# 1         55  14.42154096559389  78.45987478013856  2014-06-03T04:00:00
# 2         55  14.04361010382719  78.43363632390529  2014-06-03T03:00:00
# 3         55  13.52517004610642  78.40301469314929  2014-06-03T02:00:00
# 4         55  13.10086300817891   78.4464167072308  2014-06-03T01:00:00
# 5         55  12.44933935163495  78.47835838020622  2014-06-03T00:00:00
# 6         55  12.03758673072719  78.47933133443196  2014-06-02T23:00:00
# 7         55  11.29237019644681  78.48748757021269  2014-06-02T22:00:00
# 8         55  10.85391691923355  78.57313368055556  2014-06-02T21:00:00
#
#                        tag                                           geometry
# 0  2014_06_03_05_lat4p684N  POLYGON ((87.50000 -15.72224, 86.87500 -15.602...
# 1  2014_06_03_05_lat4p684N  POLYGON ((75.62500 -8.26274, 76.25000 -8.43109...
# 2  2014_06_03_05_lat4p684N  POLYGON ((75.62500 -8.18750, 76.25000 -8.37412...
# 3  2014_06_03_05_lat4p684N  POLYGON ((75.62500 -8.07886, 76.25000 -8.28438...
# 4  2014_06_03_05_lat4p684N  POLYGON ((76.25000 -8.20530, 76.74780 -8.00000...
# 5  2014_06_03_05_lat4p684N  POLYGON ((76.25000 -8.11945, 76.78371 -8.00000...
# 6  2014_06_03_05_lat4p684N  POLYGON ((76.25000 -8.05399, 76.87500 -8.01094...
# 7  2014_06_03_05_lat4p684N  POLYGON ((76.38087 -8.00000, 76.25000 -7.99828...
# 8  2014_06_03_05_lat4p684N  POLYGON ((76.87500 -8.05018, 77.50000 -8.00600...

# %%
gf.boundary.plot() #.time.values
# Out:
# <AxesSubplot:>

# %%
gf.time.values[0]
# Out:
# '2014-06-03T05:00:00'

# %%
dummy = gf
dummy['ftime'] = [float(dummy['time'].values[i]) for i in range(len(dummy.time))]
dummy.plot(column='ftime', alpha=0.3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-62eaa720cffe> in <module>
#       1 dummy = gf
# ----> 2 dummy['ftime'] = [float(dummy['time'].values[i]) for i in range(len(dummy.time))]
#       3 dummy.plot(column='ftime', alpha=0.3)
#
# <ipython-input-87-62eaa720cffe> in <listcomp>(.0)
#       1 dummy = gf
# ----> 2 dummy['ftime'] = [float(dummy['time'].values[i]) for i in range(len(dummy.time))]
#       3 dummy.plot(column='ftime', alpha=0.3)
#
# ValueError: could not convert string to float: '2014-06-03T05:00:00'

# %%
# !ls -atl *son
# Out:
# -rw-r--r--  1 brianmapes  staff   742 Jun 12 00:35 2014_05_15_02_lat9p247N.geojson
# -rw-r--r--  1 brianmapes  staff  5968 Jun 12 00:35 Africa_Ecoast_20NS.geojson

# %%
test = gp.read_file('2014_05_15_02_lat9p247N.geojson')
test.boundary.plot()
# Out:
# <AxesSubplot:>

# %%
test
# Out:
#   tqv_values               area             maxlon                 time  \
# 0         55  1.470142101758871  52.04622297144648  2014-05-15T02:00:00
#
#                        tag                                           geometry
# 0  2014_05_15_02_lat9p247N  POLYGON ((50.62500 8.38709, 51.25000 8.46437, ...

# %%
ccvl_stats
# Out:
#              lasttime duration  areatime  tqv_values   maxarea
# 0 2014-05-15 02:00:00   0 days  1.470142        55.0  1.470142
